# %%
import numpy as np
import torch
import deeplay as dl
import torchvision
import PIL
from torchvision import transforms
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
import sklearn 
import numpy as np
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
import os

# %%
def read_mnist_txt(file_path):
    """Read MNIST-like data from text file"""
    images = []
    labels = []
    
    with open(file_path, 'r') as file:
        for line in file:
            if not line.strip():
                continue
            parts = line.strip().split()
            image_num = parts[0].strip('"')
            label = int(parts[1])
            
            # Validate label range
            if label < -9 or label > 9:
                raise ValueError(f"Invalid label {label} found in the dataset.")
            
            pixels = list(map(float, parts[2:]))
            pixel_array = np.array(pixels).reshape(16, 16)
            images.append(pixel_array)
            labels.append(label)
    
    return np.array(images), np.array(labels)

# %%
class MNISTDataset(Dataset):
    """Custom Dataset for MNIST-like data"""
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform
        
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]
        
        # Convert to PIL Image for compatibility with torchvision transforms
        image = Image.fromarray(image.astype('float32'))
        
        if self.transform:
            image = self.transform(image)
        
        # Shift labels to zero-based indexing
        label = torch.tensor(label + 9, dtype=torch.long)
        
        return image, label

def create_cnn_model():
    """Create CNN model using deeplay"""
    conv_base = dl.ConvolutionalNeuralNetwork(
        in_channels=1, 
        hidden_channels=[16, 16, 32], 
        out_channels=32,
    )
    conv_base.blocks[2].pool.configure(torch.nn.MaxPool2d, kernel_size=2)

    connector = dl.Layer(torch.nn.AdaptiveAvgPool2d, output_size=1)

    # Update out_features to 19 for labels -9 to 9
    dense_top = dl.MultiLayerPerceptron(
        in_features=32,
        hidden_features=[64],
        out_features=19,  # Updated
        out_activation=torch.nn.LogSoftmax(dim=1)
    )

    return dl.Sequential(conv_base, connector, dense_top)

def train_cnn(train_images, train_labels,lr, epochs=20):
    """Train the CNN model and return the trained classifier."""
    # Define transforms
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])

    # Create dataset and dataloader
    train_dataset = MNISTDataset(train_images, train_labels, transform=transform)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

    # Create model
    cnn = create_cnn_model()

    # Define classifier
    class MNISTClassifier(dl.Classifier):
        def __init__(self, model, optimizer):
            super().__init__(model=model, optimizer=optimizer)
            self.loss_fn = torch.nn.NLLLoss()
        
        def training_step(self, batch, batch_idx):
            x, y = batch
            y_hat = self.model(x)
            loss = self.loss_fn(y_hat, y)
            return loss

    classifier = MNISTClassifier(
        model=cnn,
        optimizer=dl.RMSprop(lr)
    ).create()

    # Train the model
    trainer = dl.Trainer(max_epochs=epochs, accelerator="auto")
    trainer.fit(classifier, train_loader)

    return classifier


# Prediction function
def predict_with__cnn(classifier, test_images):
    """Use trained classifier to make predictions on test_images."""
    # Define transforms
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])

    # Dummy labels for test set
    test_dataset = MNISTDataset(test_images, np.zeros(len(test_images)), transform=transform)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    # Get predictions
    test_labels = []
    classifier.eval()
    with torch.no_grad():
        for x, _ in test_loader:
            y_hat = classifier.model(x)
            preds = torch.argmax(y_hat, dim=1)
            test_labels.extend((preds - 9).cpu().numpy().tolist())  # Adjust if needed

    return test_labels

# %%
#modified PCA to work with cross-validator
def dataPrep(images, labels, test_size=200):
    """Prepare and split data into train/test sets"""
    randomIndices = np.random.permutation(len(images))
    images = np.array(images)[randomIndices]
    labels = np.array(labels)[randomIndices]

    trainingSet = images[:len(images)-test_size]
    trainingLabels = labels[:len(images)-test_size]
    testSet = images[-test_size:]
    testSetLabels = labels[-test_size:]
    
    print('Shape of training set:', trainingSet.shape)
    print('Shape of test set:', testSet.shape)
    
    return trainingSet, trainingLabels, testSet, testSetLabels

# Only these 2 functions need to change:

def dimRedPCA(trainingSet, testSet=None, trainVariance=.95):
    """Modified to consistently return (data, pca) or (train_data, test_data, pca)"""
    xTrain = trainingSet.reshape(len(trainingSet), -1)
    pca = PCA(n_components=trainVariance)
    trainPCA = pca.fit_transform(xTrain)
    
    if testSet is None:
        return trainPCA, pca  # Return PCA object when no test set
    else:
        xTest = testSet.reshape(len(testSet), -1)
        return trainPCA, pca.transform(xTest), pca

def train_PCA(train_images, train_labels, max_iter=5000):
    """Training function that handles PCA"""
    train_flat = train_images.reshape(len(train_images), -1)
    train_pca, pca = dimRedPCA(train_flat)  # Now correctly unpacks 2 values
    
    clf = MLPClassifier(solver='sgd', activation='logistic', max_iter = max_iter)
    clf.fit(train_pca, train_labels)
    return clf, pca  # Return both classifier and PCA object

def predict_with_PCA(model_tuple, test_images):
    """Prediction function that applies PCA"""
    clf, pca = model_tuple
    test_flat = test_images.reshape(len(test_images), -1)
    test_pca = pca.transform(test_flat)
    return clf.predict(test_pca)

def logisticNNPCA(filePath='Numbers.txt', trainVariance=.95):
    """Original pipeline function"""
    images, labels = read_mnist_txt(filePath)
    trainingSet, trainingLabels, testSet, testSetLabels = dataPrep(images, labels)
    trainPCA, testPCA = dimRedPCA(trainingSet, testSet, trainVariance)
    
    model = train_PCA(trainPCA, trainingLabels)
    predictedLabels = predict_with_PCA(model, testPCA, testSetLabels)
    
    print(predictedLabels)
    return predictedLabels

# %%
#random forest for cross-validation
from sklearn.metrics import accuracy_score

def train_RandomForest(trainingSet, trainingLabels, n_estimators=100):
    """Train Random Forest classifier and return the trained model"""
    # Flatten images to 1D arrays
    X_train = [img.flatten() for img in trainingSet]
    
    # Initialize and train Random Forest
    rf = RandomForestClassifier(n_estimators=n_estimators, random_state=42)
    rf.fit(X_train, trainingLabels)
    
    return rf

def predict_with_RandomForest(model, testSet):
    """Make predictions using trained Random Forest model"""
    # Flatten test images to 1D arrays
    X_test = [img.flatten() for img in testSet]
    
    # Return predictions
    return model.predict(X_test)

def randomForestClassifier(trainingSet, trainingLabels, testSet, n_estimators=100):
    """Original function maintained for backward compatibility"""
    rf = train_RandomForest(trainingSet, trainingLabels, n_estimators)
    return predict_with_RandomForest(rf, testSet)

# %%
# "Training" function for k-NN (just returns training data and labels)
def train_knn_model(train_images, train_labels, k=3, norm=2):
    return {
        'train_images': train_images,
        'train_labels': train_labels,
        'k': k,
        'norm': norm
    }

# Prediction function for k-NN
def predict_knn(model, test_images):
    train_images = model['train_images']
    train_labels = model['train_labels']
    k = model['k']
    norm = model['norm']
    
    predictions = []
    for image in test_images:
        distances = [(
            np.linalg.norm(train_image - image, ord=norm), label
        ) for train_image, label in zip(train_images, train_labels)]
        
        neighbors = sorted(distances, key=lambda x: x[0])[:k]
        labels = [label for _, label in neighbors]
        predicted = max(labels, key=labels.count)
        predictions.append(predicted)
    
    return predictions

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

def cross_validate(random_state, images, labels, train_fn, predict_fn, k_folds=5, metric_fn=accuracy_score):
    """
    Generic cross-validation.

    Args:
        images (np.ndarray): Image data.
        labels (np.ndarray): Corresponding labels.
        train_fn (callable): Function to train a model. Signature: (train_images, train_labels) -> model
        predict_fn (callable): Function to predict. Signature: (model, test_images) -> predictions
        k_folds (int): Number of folds (default 5).
        metric_fn (callable): Evaluation metric function. Signature: (true_labels, predicted_labels) -> float

    Returns:
        List of scores for each fold.
    """
    all_scores = []
    kf = KFold(n_splits=k_folds, shuffle=True, random_state = random_state)

    for fold, (train_idx, val_idx) in enumerate(kf.split(images)):

        train_images, val_images = images[train_idx], images[val_idx]
        train_labels, val_labels = labels[train_idx], labels[val_idx]

        # Train and predict
        model = train_fn(train_images, train_labels)
        predictions = predict_fn(model, val_images)

        # Score
        score = metric_fn(val_labels, predictions)
        print(f"Fold {fold + 1} Score: {score:.4f}")
        all_scores.append(score)

    return all_scores

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

images, labels = read_mnist_txt("Numbers.txt")
flat_images = images.reshape(len(images), -1)
flat_images = StandardScaler().fit_transform(flat_images)

estimator_values = [5, 10, 20, 50, 100, 150, 200, 400]
repeats = 20
all_results = []

for n in estimator_values:
    print(f"Testing n_estimators = {n}")
    scores_n = []

    def train_rf(X, y): return RandomForestClassifier(n_estimators=n, random_state=42).fit(X, y)
    def predict_rf(model, X): return model.predict(X)

    for rep in range(repeats):
        scores = cross_validate(
            random_state=42 + rep,
            images=flat_images,
            labels=labels,
            train_fn=train_rf,
            predict_fn=predict_rf,
            k_folds=5,
            metric_fn=accuracy_score
        )
        scores_n.extend(scores)

    all_results.append(scores_n)

rf_errors = [1 - np.mean(scores) for scores in all_results]

plt.figure(figsize=(10, 6))
plt.plot(estimator_values, rf_errors, marker='s', linestyle='--', color='darkgreen')
plt.title("Mean Classification Error vs Number of Estimators (Random Forest)")
plt.xlabel("Number of Estimators")
plt.ylabel("Mean Classification Error")
plt.grid(True)
plt.show()
# Out:
# Testing n_estimators = 5
#
# Fold 1/5
# Fold 1 Score: 0.8225
#
# Fold 2/5
# Fold 2 Score: 0.8350
#
# Fold 3/5
# Fold 3 Score: 0.8675
#
# Fold 4/5
# Fold 4 Score: 0.8850
#
# Fold 5/5
# Fold 5 Score: 0.8000
#
# Cross-validation results:
# Mean score: 0.8420
# Std deviation: 0.0306
#
# Fold 1/5
# Fold 1 Score: 0.8550
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.8325
#
# Fold 4/5
# Fold 4 Score: 0.8525
#
# Fold 5/5
# Fold 5 Score: 0.8300
#
# Cross-validation results:
# Mean score: 0.8505
# Std deviation: 0.0189
#
# Fold 1/5
# Fold 1 Score: 0.8450
#
# Fold 2/5
# Fold 2 Score: 0.8250
#
# Fold 3/5
# Fold 3 Score: 0.8450
#
# Fold 4/5
# Fold 4 Score: 0.8200
#
# Fold 5/5
# Fold 5 Score: 0.8650
#
# Cross-validation results:
# Mean score: 0.8400
# Std deviation: 0.0161
#
# Fold 1/5
# Fold 1 Score: 0.8800
#
# Fold 2/5
# Fold 2 Score: 0.8450
#
# Fold 3/5
# Fold 3 Score: 0.8375
#
# Fold 4/5
# Fold 4 Score: 0.8650
#
# Fold 5/5
# Fold 5 Score: 0.8175
#
# Cross-validation results:
# Mean score: 0.8490
# Std deviation: 0.0217
#
# Fold 1/5
# Fold 1 Score: 0.8450
#
# Fold 2/5
# Fold 2 Score: 0.8375
#
# Fold 3/5
# Fold 3 Score: 0.8425
#
# Fold 4/5
# Fold 4 Score: 0.8675
#
# Fold 5/5
# Fold 5 Score: 0.8175
#
# Cross-validation results:
# Mean score: 0.8420
# Std deviation: 0.0160
#
# Fold 1/5
# Fold 1 Score: 0.8125
#
# Fold 2/5
# Fold 2 Score: 0.8650
#
# Fold 3/5
# Fold 3 Score: 0.8725
#
# Fold 4/5
# Fold 4 Score: 0.8250
#
# Fold 5/5
# Fold 5 Score: 0.8475
#
# Cross-validation results:
# Mean score: 0.8445
# Std deviation: 0.0229
#
# Fold 1/5
# Fold 1 Score: 0.8525
#
# Fold 2/5
# Fold 2 Score: 0.8650
#
# Fold 3/5
# Fold 3 Score: 0.8500
#
# Fold 4/5
# Fold 4 Score: 0.8350
#
# Fold 5/5
# Fold 5 Score: 0.8725
#
# Cross-validation results:
# Mean score: 0.8550
# Std deviation: 0.0129
#
# Fold 1/5
# Fold 1 Score: 0.8750
#
# Fold 2/5
# Fold 2 Score: 0.8550
#
# Fold 3/5
# Fold 3 Score: 0.8650
#
# Fold 4/5
# Fold 4 Score: 0.8450
#
# Fold 5/5
# Fold 5 Score: 0.8575
#
# Cross-validation results:
# Mean score: 0.8595
# Std deviation: 0.0100
#
# Fold 1/5
# Fold 1 Score: 0.8550
#
# Fold 2/5
# Fold 2 Score: 0.8750
#
# Fold 3/5
# Fold 3 Score: 0.8525
#
# Fold 4/5
# Fold 4 Score: 0.8675
#
# Fold 5/5
# Fold 5 Score: 0.8450
#
# Cross-validation results:
# Mean score: 0.8590
# Std deviation: 0.0108
#
# Fold 1/5
# Fold 1 Score: 0.8350
#
# Fold 2/5
# Fold 2 Score: 0.8450
#
# Fold 3/5
# Fold 3 Score: 0.8750
#
# Fold 4/5
# Fold 4 Score: 0.8450
#
# Fold 5/5
# Fold 5 Score: 0.8350
#
# Cross-validation results:
# Mean score: 0.8470
# Std deviation: 0.0147
#
# Fold 1/5
# Fold 1 Score: 0.8800
#
# Fold 2/5
# Fold 2 Score: 0.8250
#
# Fold 3/5
# Fold 3 Score: 0.8075
#
# Fold 4/5
# Fold 4 Score: 0.8525
#
# Fold 5/5
# Fold 5 Score: 0.8575
#
# Cross-validation results:
# Mean score: 0.8445
# Std deviation: 0.0255
#
# Fold 1/5
# Fold 1 Score: 0.8600
#
# Fold 2/5
# Fold 2 Score: 0.8350
#
# Fold 3/5
# Fold 3 Score: 0.8575
#
# Fold 4/5
# Fold 4 Score: 0.8700
#
# Fold 5/5
# Fold 5 Score: 0.8500
#
# Cross-validation results:
# Mean score: 0.8545
# Std deviation: 0.0117
#
# Fold 1/5
# Fold 1 Score: 0.8400
#
# Fold 2/5
# Fold 2 Score: 0.8150
#
# Fold 3/5
# Fold 3 Score: 0.8650
#
# Fold 4/5
# Fold 4 Score: 0.8500
#
# Fold 5/5
# Fold 5 Score: 0.8475
#
# Cross-validation results:
# Mean score: 0.8435
# Std deviation: 0.0164
#
# Fold 1/5
# Fold 1 Score: 0.8675
#
# Fold 2/5
# Fold 2 Score: 0.8550
#
# Fold 3/5
# Fold 3 Score: 0.8200
#
# Fold 4/5
# Fold 4 Score: 0.8275
#
# Fold 5/5
# Fold 5 Score: 0.8525
#
# Cross-validation results:
# Mean score: 0.8445
# Std deviation: 0.0178
#
# Fold 1/5
# Fold 1 Score: 0.8650
#
# Fold 2/5
# Fold 2 Score: 0.8400
#
# Fold 3/5
# Fold 3 Score: 0.8700
#
# Fold 4/5
# Fold 4 Score: 0.8575
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.8645
# Std deviation: 0.0163
#
# Fold 1/5
# Fold 1 Score: 0.8700
#
# Fold 2/5
# Fold 2 Score: 0.8475
#
# Fold 3/5
# Fold 3 Score: 0.8600
#
# Fold 4/5
# Fold 4 Score: 0.8400
#
# Fold 5/5
# Fold 5 Score: 0.8300
#
# Cross-validation results:
# Mean score: 0.8495
# Std deviation: 0.0142
#
# Fold 1/5
# Fold 1 Score: 0.8625
#
# Fold 2/5
# Fold 2 Score: 0.8650
#
# Fold 3/5
# Fold 3 Score: 0.8675
#
# Fold 4/5
# Fold 4 Score: 0.8200
#
# Fold 5/5
# Fold 5 Score: 0.8700
#
# Cross-validation results:
# Mean score: 0.8570
# Std deviation: 0.0187
#
# Fold 1/5
# Fold 1 Score: 0.8600
#
# Fold 2/5
# Fold 2 Score: 0.8500
#
# Fold 3/5
# Fold 3 Score: 0.8875
#
# Fold 4/5
# Fold 4 Score: 0.8525
#
# Fold 5/5
# Fold 5 Score: 0.8525
#
# Cross-validation results:
# Mean score: 0.8605
# Std deviation: 0.0139
#
# Fold 1/5
# Fold 1 Score: 0.8875
#
# Fold 2/5
# Fold 2 Score: 0.8650
#
# Fold 3/5
# Fold 3 Score: 0.8450
#
# Fold 4/5
# Fold 4 Score: 0.8475
#
# Fold 5/5
# Fold 5 Score: 0.8625
#
# Cross-validation results:
# Mean score: 0.8615
# Std deviation: 0.0152
#
# Fold 1/5
# Fold 1 Score: 0.8475
#
# Fold 2/5
# Fold 2 Score: 0.8650
#
# Fold 3/5
# Fold 3 Score: 0.8575
#
# Fold 4/5
# Fold 4 Score: 0.8475
#
# Fold 5/5
# Fold 5 Score: 0.8725
#
# Cross-validation results:
# Mean score: 0.8580
# Std deviation: 0.0098
# Testing n_estimators = 10
#
# Fold 1/5
# Fold 1 Score: 0.8750
#
# Fold 2/5
# Fold 2 Score: 0.8725
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.8750
#
# Cross-validation results:
# Mean score: 0.8895
# Std deviation: 0.0188
#
# Fold 1/5
# Fold 1 Score: 0.8800
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.8675
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.8915
# Std deviation: 0.0174
#
# Fold 1/5
# Fold 1 Score: 0.8875
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.9075
#
# Fold 4/5
# Fold 4 Score: 0.8775
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.8920
# Std deviation: 0.0121
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.8875
#
# Fold 3/5
# Fold 3 Score: 0.8850
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.8575
#
# Cross-validation results:
# Mean score: 0.8900
# Std deviation: 0.0197
#
# Fold 1/5
# Fold 1 Score: 0.8850
#
# Fold 2/5
# Fold 2 Score: 0.8925
#
# Fold 3/5
# Fold 3 Score: 0.8950
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.8875
#
# Cross-validation results:
# Mean score: 0.8955
# Std deviation: 0.0116
#
# Fold 1/5
# Fold 1 Score: 0.8700
#
# Fold 2/5
# Fold 2 Score: 0.9000
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.8775
#
# Fold 5/5
# Fold 5 Score: 0.8800
#
# Cross-validation results:
# Mean score: 0.8880
# Std deviation: 0.0158
#
# Fold 1/5
# Fold 1 Score: 0.8875
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.8950
#
# Fold 4/5
# Fold 4 Score: 0.8900
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.8955
# Std deviation: 0.0078
#
# Fold 1/5
# Fold 1 Score: 0.9025
#
# Fold 2/5
# Fold 2 Score: 0.8875
#
# Fold 3/5
# Fold 3 Score: 0.9075
#
# Fold 4/5
# Fold 4 Score: 0.8750
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.8955
# Std deviation: 0.0124
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.8925
#
# Fold 4/5
# Fold 4 Score: 0.8950
#
# Fold 5/5
# Fold 5 Score: 0.8650
#
# Cross-validation results:
# Mean score: 0.8965
# Std deviation: 0.0190
#
# Fold 1/5
# Fold 1 Score: 0.8875
#
# Fold 2/5
# Fold 2 Score: 0.8875
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.8700
#
# Fold 5/5
# Fold 5 Score: 0.8775
#
# Cross-validation results:
# Mean score: 0.8890
# Std deviation: 0.0180
#
# Fold 1/5
# Fold 1 Score: 0.9000
#
# Fold 2/5
# Fold 2 Score: 0.8875
#
# Fold 3/5
# Fold 3 Score: 0.8600
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.8915
# Std deviation: 0.0181
#
# Fold 1/5
# Fold 1 Score: 0.8900
#
# Fold 2/5
# Fold 2 Score: 0.8475
#
# Fold 3/5
# Fold 3 Score: 0.9050
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.8890
# Std deviation: 0.0225
#
# Fold 1/5
# Fold 1 Score: 0.8875
#
# Fold 2/5
# Fold 2 Score: 0.8625
#
# Fold 3/5
# Fold 3 Score: 0.9025
#
# Fold 4/5
# Fold 4 Score: 0.8900
#
# Fold 5/5
# Fold 5 Score: 0.9000
#
# Cross-validation results:
# Mean score: 0.8885
# Std deviation: 0.0142
#
# Fold 1/5
# Fold 1 Score: 0.9025
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.8750
#
# Fold 4/5
# Fold 4 Score: 0.8975
#
# Fold 5/5
# Fold 5 Score: 0.8800
#
# Cross-validation results:
# Mean score: 0.8920
# Std deviation: 0.0122
#
# Fold 1/5
# Fold 1 Score: 0.8975
#
# Fold 2/5
# Fold 2 Score: 0.8750
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.8960
# Std deviation: 0.0117
#
# Fold 1/5
# Fold 1 Score: 0.8825
#
# Fold 2/5
# Fold 2 Score: 0.8875
#
# Fold 3/5
# Fold 3 Score: 0.8950
#
# Fold 4/5
# Fold 4 Score: 0.8950
#
# Fold 5/5
# Fold 5 Score: 0.8750
#
# Cross-validation results:
# Mean score: 0.8870
# Std deviation: 0.0076
#
# Fold 1/5
# Fold 1 Score: 0.8700
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9050
#
# Fold 4/5
# Fold 4 Score: 0.8700
#
# Fold 5/5
# Fold 5 Score: 0.8875
#
# Cross-validation results:
# Mean score: 0.8920
# Std deviation: 0.0220
#
# Fold 1/5
# Fold 1 Score: 0.8875
#
# Fold 2/5
# Fold 2 Score: 0.8800
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.9000
#
# Cross-validation results:
# Mean score: 0.8980
# Std deviation: 0.0132
#
# Fold 1/5
# Fold 1 Score: 0.8925
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.8775
#
# Fold 4/5
# Fold 4 Score: 0.8900
#
# Fold 5/5
# Fold 5 Score: 0.8925
#
# Cross-validation results:
# Mean score: 0.8895
# Std deviation: 0.0062
#
# Fold 1/5
# Fold 1 Score: 0.9075
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.8900
#
# Fold 4/5
# Fold 4 Score: 0.8775
#
# Fold 5/5
# Fold 5 Score: 0.8850
#
# Cross-validation results:
# Mean score: 0.8930
# Std deviation: 0.0116
# Testing n_estimators = 20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9100
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9425
#
# Fold 5/5
# Fold 5 Score: 0.9075
#
# Cross-validation results:
# Mean score: 0.9195
# Std deviation: 0.0130
#
# Fold 1/5
# Fold 1 Score: 0.9000
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.8925
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9105
# Std deviation: 0.0137
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9205
# Std deviation: 0.0103
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.8775
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0222
#
# Fold 1/5
# Fold 1 Score: 0.8950
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.9075
#
# Cross-validation results:
# Mean score: 0.9105
# Std deviation: 0.0108
#
# Fold 1/5
# Fold 1 Score: 0.8975
#
# Fold 2/5
# Fold 2 Score: 0.9025
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.9080
# Std deviation: 0.0125
#
# Fold 1/5
# Fold 1 Score: 0.9050
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9000
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9120
# Std deviation: 0.0094
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.8900
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9155
# Std deviation: 0.0132
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9075
#
# Cross-validation results:
# Mean score: 0.9135
# Std deviation: 0.0112
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9000
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9160
# Std deviation: 0.0110
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9000
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0100
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.8750
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9145
# Std deviation: 0.0206
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9375
#
# Cross-validation results:
# Mean score: 0.9160
# Std deviation: 0.0155
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9215
# Std deviation: 0.0064
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9205
# Std deviation: 0.0124
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9000
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9075
#
# Cross-validation results:
# Mean score: 0.9125
# Std deviation: 0.0079
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9425
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9000
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9255
# Std deviation: 0.0143
#
# Fold 1/5
# Fold 1 Score: 0.8925
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9425
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9170
# Std deviation: 0.0162
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0050
#
# Fold 1/5
# Fold 1 Score: 0.9375
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.8925
#
# Fold 5/5
# Fold 5 Score: 0.9125
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0161
# Testing n_estimators = 50
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9500
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9325
# Std deviation: 0.0118
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9400
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9260
# Std deviation: 0.0106
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.9425
#
# Cross-validation results:
# Mean score: 0.9305
# Std deviation: 0.0113
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9400
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.9265
# Std deviation: 0.0176
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9400
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9285
# Std deviation: 0.0066
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9225
# Std deviation: 0.0129
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9275
# Std deviation: 0.0069
#
# Fold 1/5
# Fold 1 Score: 0.9400
#
# Fold 2/5
# Fold 2 Score: 0.9100
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9290
# Std deviation: 0.0142
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9285
# Std deviation: 0.0106
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9240
# Std deviation: 0.0090
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9270
# Std deviation: 0.0122
#
# Fold 1/5
# Fold 1 Score: 0.9375
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9475
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9260
# Std deviation: 0.0177
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9425
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9240
# Std deviation: 0.0147
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9255
# Std deviation: 0.0095
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.9450
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9270
# Std deviation: 0.0145
#
# Fold 1/5
# Fold 1 Score: 0.9350
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9240
# Std deviation: 0.0093
#
# Fold 1/5
# Fold 1 Score: 0.9250
#
# Fold 2/5
# Fold 2 Score: 0.9450
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.8925
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9285
# Std deviation: 0.0202
#
# Fold 1/5
# Fold 1 Score: 0.9050
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9400
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9255
# Std deviation: 0.0121
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9280
# Std deviation: 0.0094
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9425
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9300
# Std deviation: 0.0081
# Testing n_estimators = 100
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9475
#
# Fold 5/5
# Fold 5 Score: 0.9425
#
# Cross-validation results:
# Mean score: 0.9345
# Std deviation: 0.0097
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9475
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9500
#
# Fold 5/5
# Fold 5 Score: 0.9500
#
# Cross-validation results:
# Mean score: 0.9400
# Std deviation: 0.0115
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9475
#
# Cross-validation results:
# Mean score: 0.9350
# Std deviation: 0.0127
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9425
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9425
#
# Fold 5/5
# Fold 5 Score: 0.8925
#
# Cross-validation results:
# Mean score: 0.9285
# Std deviation: 0.0208
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9425
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9305
# Std deviation: 0.0093
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9310
# Std deviation: 0.0106
#
# Fold 1/5
# Fold 1 Score: 0.9375
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9310
# Std deviation: 0.0072
#
# Fold 1/5
# Fold 1 Score: 0.9400
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9375
#
# Cross-validation results:
# Mean score: 0.9340
# Std deviation: 0.0125
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9475
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9360
# Std deviation: 0.0106
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9425
#
# Cross-validation results:
# Mean score: 0.9270
# Std deviation: 0.0114
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9350
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9310
# Std deviation: 0.0075
#
# Fold 1/5
# Fold 1 Score: 0.9400
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9500
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9305
# Std deviation: 0.0150
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9400
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9525
#
# Cross-validation results:
# Mean score: 0.9285
# Std deviation: 0.0150
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9425
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9315
# Std deviation: 0.0111
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9100
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9290
# Std deviation: 0.0149
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9375
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9300
# Std deviation: 0.0128
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.9500
#
# Fold 3/5
# Fold 3 Score: 0.9450
#
# Fold 4/5
# Fold 4 Score: 0.8950
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9275
# Std deviation: 0.0196
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9270
# Std deviation: 0.0119
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9350
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9475
#
# Cross-validation results:
# Mean score: 0.9305
# Std deviation: 0.0099
#
# Fold 1/5
# Fold 1 Score: 0.9350
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9325
#
# Cross-validation results:
# Mean score: 0.9310
# Std deviation: 0.0094
# Testing n_estimators = 150
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9500
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9365
# Std deviation: 0.0078
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9450
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9500
#
# Fold 5/5
# Fold 5 Score: 0.9475
#
# Cross-validation results:
# Mean score: 0.9385
# Std deviation: 0.0112
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9475
#
# Cross-validation results:
# Mean score: 0.9350
# Std deviation: 0.0130
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9425
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9450
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9315
# Std deviation: 0.0175
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9375
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9280
# Std deviation: 0.0058
#
# Fold 1/5
# Fold 1 Score: 0.9375
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9340
# Std deviation: 0.0090
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9330
# Std deviation: 0.0089
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9550
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9375
#
# Cross-validation results:
# Mean score: 0.9365
# Std deviation: 0.0147
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9425
#
# Fold 5/5
# Fold 5 Score: 0.9450
#
# Cross-validation results:
# Mean score: 0.9400
# Std deviation: 0.0076
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9260
# Std deviation: 0.0098
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9325
#
# Cross-validation results:
# Mean score: 0.9315
# Std deviation: 0.0090
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9450
#
# Fold 5/5
# Fold 5 Score: 0.9325
#
# Cross-validation results:
# Mean score: 0.9330
# Std deviation: 0.0107
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9450
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9525
#
# Cross-validation results:
# Mean score: 0.9305
# Std deviation: 0.0154
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9500
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9365
# Std deviation: 0.0114
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9315
# Std deviation: 0.0151
#
# Fold 1/5
# Fold 1 Score: 0.9550
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9315
# Std deviation: 0.0137
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9475
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9330
# Std deviation: 0.0137
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9375
#
# Cross-validation results:
# Mean score: 0.9290
# Std deviation: 0.0136
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9450
#
# Cross-validation results:
# Mean score: 0.9335
# Std deviation: 0.0068
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9475
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9340
# Std deviation: 0.0097
# Testing n_estimators = 200
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9450
#
# Fold 5/5
# Fold 5 Score: 0.9450
#
# Cross-validation results:
# Mean score: 0.9360
# Std deviation: 0.0078
#
# Fold 1/5
# Fold 1 Score: 0.9350
#
# Fold 2/5
# Fold 2 Score: 0.9425
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9525
#
# Fold 5/5
# Fold 5 Score: 0.9375
#
# Cross-validation results:
# Mean score: 0.9380
# Std deviation: 0.0098
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9500
#
# Cross-validation results:
# Mean score: 0.9355
# Std deviation: 0.0123
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9400
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9450
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.9320
# Std deviation: 0.0169
#
# Fold 1/5
# Fold 1 Score: 0.9350
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9290
# Std deviation: 0.0060
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9320
# Std deviation: 0.0089
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9450
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9310
# Std deviation: 0.0112
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9355
# Std deviation: 0.0127
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9375
#
# Fold 5/5
# Fold 5 Score: 0.9425
#
# Cross-validation results:
# Mean score: 0.9400
# Std deviation: 0.0059
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9100
#
# Fold 5/5
# Fold 5 Score: 0.9425
#
# Cross-validation results:
# Mean score: 0.9260
# Std deviation: 0.0125
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9325
#
# Cross-validation results:
# Mean score: 0.9325
# Std deviation: 0.0079
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9500
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9360
# Std deviation: 0.0107
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.9525
#
# Cross-validation results:
# Mean score: 0.9330
# Std deviation: 0.0142
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9525
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9375
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9385
# Std deviation: 0.0125
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9100
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9325
# Std deviation: 0.0155
#
# Fold 1/5
# Fold 1 Score: 0.9525
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9375
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9320
# Std deviation: 0.0121
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9475
#
# Fold 3/5
# Fold 3 Score: 0.9450
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9320
# Std deviation: 0.0121
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9550
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9300
# Std deviation: 0.0154
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9425
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9450
#
# Cross-validation results:
# Mean score: 0.9355
# Std deviation: 0.0070
#
# Fold 1/5
# Fold 1 Score: 0.9350
#
# Fold 2/5
# Fold 2 Score: 0.9525
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9375
#
# Cross-validation results:
# Mean score: 0.9355
# Std deviation: 0.0111
# Testing n_estimators = 400
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9525
#
# Fold 5/5
# Fold 5 Score: 0.9375
#
# Cross-validation results:
# Mean score: 0.9375
# Std deviation: 0.0082
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9450
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9475
#
# Fold 5/5
# Fold 5 Score: 0.9375
#
# Cross-validation results:
# Mean score: 0.9375
# Std deviation: 0.0082
#
# Fold 1/5
# Fold 1 Score: 0.9400
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9400
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.9575
#
# Cross-validation results:
# Mean score: 0.9375
# Std deviation: 0.0136
#
# Fold 1/5
# Fold 1 Score: 0.9525
#
# Fold 2/5
# Fold 2 Score: 0.9450
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9450
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9330
# Std deviation: 0.0188
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9375
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9330
# Std deviation: 0.0084
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9335
# Std deviation: 0.0086
#
# Fold 1/5
# Fold 1 Score: 0.9375
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9450
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9335
# Std deviation: 0.0104
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9425
#
# Cross-validation results:
# Mean score: 0.9365
# Std deviation: 0.0119
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9350
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9475
#
# Fold 5/5
# Fold 5 Score: 0.9375
#
# Cross-validation results:
# Mean score: 0.9395
# Std deviation: 0.0058
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9500
#
# Cross-validation results:
# Mean score: 0.9320
# Std deviation: 0.0152
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9345
# Std deviation: 0.0094
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9475
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9335
# Std deviation: 0.0129
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9525
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9550
#
# Cross-validation results:
# Mean score: 0.9360
# Std deviation: 0.0153
#
# Fold 1/5
# Fold 1 Score: 0.9500
#
# Fold 2/5
# Fold 2 Score: 0.9500
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9375
# Std deviation: 0.0120
#
# Fold 1/5
# Fold 1 Score: 0.9475
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9450
#
# Fold 4/5
# Fold 4 Score: 0.9375
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9340
# Std deviation: 0.0120
#
# Fold 1/5
# Fold 1 Score: 0.9450
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9400
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9315
# Std deviation: 0.0094
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9525
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9350
# Std deviation: 0.0126
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9575
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9325
# Std deviation: 0.0142
#
# Fold 1/5
# Fold 1 Score: 0.9400
#
# Fold 2/5
# Fold 2 Score: 0.9450
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9425
#
# Cross-validation results:
# Mean score: 0.9385
# Std deviation: 0.0054
#
# Fold 1/5
# Fold 1 Score: 0.9350
#
# Fold 2/5
# Fold 2 Score: 0.9500
#
# Fold 3/5
# Fold 3 Score: 0.9425
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9360
# Std deviation: 0.0127

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming all_results contains accuracy scores per k
estimator_values = [5, 10, 20, 50, 100, 150, 200, 400]

# Convert accuracy to error (1 - accuracy) for each score
rf_errors = [1 - np.mean(scores) for scores in all_results]

plt.figure(figsize=(10, 6))
plt.boxplot(rf_errors, labels=[str(k) for k in estimator_values], patch_artist=True)
plt.title("k-NN Classification Error vs Number of Neighbors")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Classification Error (1 - Accuracy)")
plt.grid(True)
plt.show()
# Out:
# C:\Users\Nils\AppData\Local\Temp\ipykernel_17508\3491108252.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(rf_errors, labels=[str(k) for k in estimator_values], patch_artist=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 11
#       8 rf_errors = [1 - np.mean(scores) for scores in all_results]
#      10 plt.figure(figsize=(10, 6))
# ---> 11 plt.boxplot(rf_errors, labels=[str(k) for k in estimator_values], patch_artist=True)
#      12 plt.title("k-NN Classification Error vs Number of Neighbors")
#      13 plt.xlabel("Number of Neighbors (k)")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\_api\deprecation.py:300, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     295     warn_deprecated(
#     296         since, message=f"The {old!r} parameter of {func.__name__}() "
#     297         f"has been renamed {new!r} since Matplotlib {since}; support "
#     298         f"for the old name will be dropped %(removal)s.")
#     299     kwargs[new] = kwargs.pop(old)
# --> 300 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\pyplot.py:3051, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label, data)
#    3018 @_copy_docstring_and_deprecators(Axes.boxplot)
#    3019 def boxplot(
#    3020     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3049     data=None,
#    3050 ) -> dict[str, Any]:
# -> 3051     return gca().boxplot(
#    3052         x,
#    3053         notch=notch,
#    3054         sym=sym,
#    3055         vert=vert,
#    3056         whis=whis,
#    3057         positions=positions,
#    3058         widths=widths,
#    3059         patch_artist=patch_artist,
#    3060         bootstrap=bootstrap,
#    3061         usermedians=usermedians,
#    3062         conf_intervals=conf_intervals,
#    3063         meanline=meanline,
#    3064         showmeans=showmeans,
#    3065         showcaps=showcaps,
#    3066         showbox=showbox,
#    3067         showfliers=showfliers,
#    3068         boxprops=boxprops,
#    3069         tick_labels=tick_labels,
#    3070         flierprops=flierprops,
#    3071         medianprops=medianprops,
#    3072         meanprops=meanprops,
#    3073         capprops=capprops,
#    3074         whiskerprops=whiskerprops,
#    3075         manage_ticks=manage_ticks,
#    3076         autorange=autorange,
#    3077         zorder=zorder,
#    3078         capwidths=capwidths,
#    3079         label=label,
#    3080         **({"data": data} if data is not None else {}),
#    3081     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\_api\deprecation.py:300, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     295     warn_deprecated(
#     296         since, message=f"The {old!r} parameter of {func.__name__}() "
#     297         f"has been renamed {new!r} since Matplotlib {since}; support "
#     298         f"for the old name will be dropped %(removal)s.")
#     299     kwargs[new] = kwargs.pop(old)
# --> 300 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\axes\_axes.py:4039, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, tick_labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, label)
#    4036 if bootstrap is None:
#    4037     bootstrap = mpl.rcParams['boxplot.bootstrap']
# -> 4039 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    4040                                labels=tick_labels, autorange=autorange)
#    4041 if notch is None:
#    4042     notch = mpl.rcParams['boxplot.notch']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\cbook.py:1260, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1258     labels = itertools.repeat(None)
#    1259 elif len(labels) != ncols:
# -> 1260     raise ValueError("Dimensions of labels and X must be compatible")
#    1262 input_whis = whis
#    1263 for ii, (x, label) in enumerate(zip(X, labels)):
#    1264
#    1265     # empty dict
#
# ValueError: Dimensions of labels and X must be compatible

# %%
#tune knn with CV
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from functools import partial

if __name__ == "__main__":
    # Load and preprocess
    images, labels = read_mnist_txt("Numbers.txt")
    flat_images = images.reshape(len(images), -1)
    flat_images = StandardScaler().fit_transform(flat_images)

    # k values to test
    k_values = [1, 3, 5, 7, 10, 15, 25, 40]
    repeats = 20
    all_results = []

    print("Starting cross-validation...\n")

    for k in k_values:
        print(f"Testing k = {k}")
        scores_k = []
        train_fn = partial(train_knn_model, k=k, norm=2)

        for rep in range(repeats):
            print(f"  Repeat {rep + 1}/{repeats}")
            scores = cross_validate(
                random_state=42 + rep,
                images=flat_images,
                labels=labels,
                train_fn=train_fn,
                predict_fn=predict_knn,
                k_folds=5,
                metric_fn=accuracy_score
            )
            scores_k.extend(scores)

        all_results.append(scores_k)

    # Compute mean classification error for each k
knn_mean_errors = [1 - np.mean(scores) for scores in all_results]

plt.figure(figsize=(8, 5))
plt.plot(k_values, knn_mean_errors, marker='o', linestyle='-', color='purple')
plt.title("Mean Classification Error vs. k (k-NN)")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Mean Classification Error")
plt.grid(True)
plt.show()

for i, k in enumerate(k_values):
    sorted_scores = sorted(all_results[i])
    print(f"\nk = {k}, Sorted Accuracy Scores ({len(sorted_scores)} values):")
    print(sorted_scores)
# Out:
# Starting cross-validation...
#
# Testing k = 1
#   Repeat 1/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9215
# Std deviation: 0.0056
#   Repeat 2/20
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9100
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9210
# Std deviation: 0.0085
#   Repeat 3/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9000
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9450
#
# Cross-validation results:
# Mean score: 0.9200
# Std deviation: 0.0157
#   Repeat 4/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.8900
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.9000
#
# Cross-validation results:
# Mean score: 0.9100
# Std deviation: 0.0133
#   Repeat 5/20
#
# Fold 1/5
# Fold 1 Score: 0.9250
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.9155
# Std deviation: 0.0136
#   Repeat 6/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9170
# Std deviation: 0.0081
#   Repeat 7/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9205
# Std deviation: 0.0029
#   Repeat 8/20
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9195
# Std deviation: 0.0089
#   Repeat 9/20
#
# Fold 1/5
# Fold 1 Score: 0.9350
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9135
# Std deviation: 0.0138
#   Repeat 10/20
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9400
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9220
# Std deviation: 0.0104
#   Repeat 11/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.8975
#
# Cross-validation results:
# Mean score: 0.9120
# Std deviation: 0.0109
#   Repeat 12/20
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9190
# Std deviation: 0.0125
#   Repeat 13/20
#
# Fold 1/5
# Fold 1 Score: 0.8975
#
# Fold 2/5
# Fold 2 Score: 0.8975
#
# Fold 3/5
# Fold 3 Score: 0.9450
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9170
# Std deviation: 0.0211
#   Repeat 14/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9190
# Std deviation: 0.0092
#   Repeat 15/20
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.8875
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9180
# Std deviation: 0.0190
#   Repeat 16/20
#
# Fold 1/5
# Fold 1 Score: 0.9375
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0133
#   Repeat 17/20
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.9400
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.8925
#
# Cross-validation results:
# Mean score: 0.9170
# Std deviation: 0.0187
#   Repeat 18/20
#
# Fold 1/5
# Fold 1 Score: 0.9000
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9425
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9155
# Std deviation: 0.0148
#   Repeat 19/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9050
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9170
# Std deviation: 0.0102
#   Repeat 20/20
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.9425
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.8900
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9185
# Std deviation: 0.0167
# Testing k = 3
#   Repeat 1/20
#
# Fold 1/5
# Fold 1 Score: 0.9050
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9215
# Std deviation: 0.0094
#   Repeat 2/20
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9235
# Std deviation: 0.0034
#   Repeat 3/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9025
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.9500
#
# Cross-validation results:
# Mean score: 0.9200
# Std deviation: 0.0178
#   Repeat 4/20
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9075
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.9200
# Std deviation: 0.0188
#   Repeat 5/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9170
# Std deviation: 0.0037
#   Repeat 6/20
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9215
# Std deviation: 0.0086
#   Repeat 7/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9100
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9220
# Std deviation: 0.0078
#   Repeat 8/20
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9100
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9245
# Std deviation: 0.0100
#   Repeat 9/20
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9025
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9180
# Std deviation: 0.0091
#   Repeat 10/20
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9000
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9210
# Std deviation: 0.0115
#   Repeat 11/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9425
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9180
# Std deviation: 0.0133
#   Repeat 12/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.8750
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9375
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0232
#   Repeat 13/20
#
# Fold 1/5
# Fold 1 Score: 0.8925
#
# Fold 2/5
# Fold 2 Score: 0.8925
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9425
#
# Cross-validation results:
# Mean score: 0.9155
# Std deviation: 0.0199
#   Repeat 14/20
#
# Fold 1/5
# Fold 1 Score: 0.9375
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9255
# Std deviation: 0.0113
#   Repeat 15/20
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9180
# Std deviation: 0.0223
#   Repeat 16/20
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9100
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9200
# Std deviation: 0.0140
#   Repeat 17/20
#
# Fold 1/5
# Fold 1 Score: 0.9050
#
# Fold 2/5
# Fold 2 Score: 0.9400
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9000
#
# Cross-validation results:
# Mean score: 0.9190
# Std deviation: 0.0166
#   Repeat 18/20
#
# Fold 1/5
# Fold 1 Score: 0.8975
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9425
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9205
# Std deviation: 0.0148
#   Repeat 19/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9350
#
# Cross-validation results:
# Mean score: 0.9235
# Std deviation: 0.0072
#   Repeat 20/20
#
# Fold 1/5
# Fold 1 Score: 0.9250
#
# Fold 2/5
# Fold 2 Score: 0.9400
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.8975
#
# Fold 5/5
# Fold 5 Score: 0.9125
#
# Cross-validation results:
# Mean score: 0.9205
# Std deviation: 0.0144
# Testing k = 5
#   Repeat 1/20
#
# Fold 1/5
# Fold 1 Score: 0.8950
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9180
# Std deviation: 0.0122
#   Repeat 2/20
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0082
#   Repeat 3/20
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9425
#
# Cross-validation results:
# Mean score: 0.9205
# Std deviation: 0.0127
#   Repeat 4/20
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.9150
# Std deviation: 0.0141
#   Repeat 5/20
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9155
# Std deviation: 0.0066
#   Repeat 6/20
#
# Fold 1/5
# Fold 1 Score: 0.8925
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.9500
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9075
#
# Cross-validation results:
# Mean score: 0.9140
# Std deviation: 0.0192
#   Repeat 7/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9200
# Std deviation: 0.0057
#   Repeat 8/20
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.9400
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9325
#
# Cross-validation results:
# Mean score: 0.9240
# Std deviation: 0.0129
#   Repeat 9/20
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.8850
#
# Fold 3/5
# Fold 3 Score: 0.9075
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9130
# Std deviation: 0.0162
#   Repeat 10/20
#
# Fold 1/5
# Fold 1 Score: 0.9075
#
# Fold 2/5
# Fold 2 Score: 0.9350
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.8925
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9150
# Std deviation: 0.0146
#   Repeat 11/20
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9400
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.8950
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0143
#   Repeat 12/20
#
# Fold 1/5
# Fold 1 Score: 0.9250
#
# Fold 2/5
# Fold 2 Score: 0.8750
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9375
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9190
# Std deviation: 0.0224
#   Repeat 13/20
#
# Fold 1/5
# Fold 1 Score: 0.9050
#
# Fold 2/5
# Fold 2 Score: 0.8925
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9325
#
# Cross-validation results:
# Mean score: 0.9180
# Std deviation: 0.0163
#   Repeat 14/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9210
# Std deviation: 0.0089
#   Repeat 15/20
#
# Fold 1/5
# Fold 1 Score: 0.9300
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.9400
#
# Fold 4/5
# Fold 4 Score: 0.9000
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9155
# Std deviation: 0.0211
#   Repeat 16/20
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0063
#   Repeat 17/20
#
# Fold 1/5
# Fold 1 Score: 0.9025
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.9160
# Std deviation: 0.0137
#   Repeat 18/20
#
# Fold 1/5
# Fold 1 Score: 0.9050
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9185
# Std deviation: 0.0156
#   Repeat 19/20
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.8925
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9175
# Std deviation: 0.0130
#   Repeat 20/20
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9450
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.8975
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9165
# Std deviation: 0.0156
# Testing k = 7
#   Repeat 1/20
#
# Fold 1/5
# Fold 1 Score: 0.8925
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9075
#
# Cross-validation results:
# Mean score: 0.9135
# Std deviation: 0.0129
#   Repeat 2/20
#
# Fold 1/5
# Fold 1 Score: 0.9025
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.9125
# Std deviation: 0.0115
#   Repeat 3/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.8925
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9100
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9145
# Std deviation: 0.0153
#   Repeat 4/20
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.8925
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.8925
#
# Cross-validation results:
# Mean score: 0.9105
# Std deviation: 0.0157
#   Repeat 5/20
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9075
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9125
# Std deviation: 0.0032
#   Repeat 6/20
#
# Fold 1/5
# Fold 1 Score: 0.8850
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.9450
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.9000
#
# Cross-validation results:
# Mean score: 0.9080
# Std deviation: 0.0199
#   Repeat 7/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.8925
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9110
# Std deviation: 0.0109
#   Repeat 8/20
#
# Fold 1/5
# Fold 1 Score: 0.8975
#
# Fold 2/5
# Fold 2 Score: 0.8975
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9140
# Std deviation: 0.0141
#   Repeat 9/20
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.9050
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.9125
#
# Cross-validation results:
# Mean score: 0.9090
# Std deviation: 0.0149
#   Repeat 10/20
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.8975
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9090
# Std deviation: 0.0086
#   Repeat 11/20
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.8875
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9130
# Std deviation: 0.0148
#   Repeat 12/20
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9135
# Std deviation: 0.0160
#   Repeat 13/20
#
# Fold 1/5
# Fold 1 Score: 0.8900
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9105
# Std deviation: 0.0201
#   Repeat 14/20
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.8975
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.9115
# Std deviation: 0.0125
#   Repeat 15/20
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.8725
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9110
# Std deviation: 0.0208
#   Repeat 16/20
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9100
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9250
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9185
# Std deviation: 0.0089
#   Repeat 17/20
#
# Fold 1/5
# Fold 1 Score: 0.8875
#
# Fold 2/5
# Fold 2 Score: 0.9350
#
# Fold 3/5
# Fold 3 Score: 0.9300
#
# Fold 4/5
# Fold 4 Score: 0.9000
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9110
# Std deviation: 0.0183
#   Repeat 18/20
#
# Fold 1/5
# Fold 1 Score: 0.9000
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9400
#
# Fold 4/5
# Fold 4 Score: 0.8975
#
# Fold 5/5
# Fold 5 Score: 0.9075
#
# Cross-validation results:
# Mean score: 0.9115
# Std deviation: 0.0152
#   Repeat 19/20
#
# Fold 1/5
# Fold 1 Score: 0.9250
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.8925
#
# Fold 4/5
# Fold 4 Score: 0.9225
#
# Fold 5/5
# Fold 5 Score: 0.9325
#
# Cross-validation results:
# Mean score: 0.9135
# Std deviation: 0.0165
#   Repeat 20/20
#
# Fold 1/5
# Fold 1 Score: 0.9075
#
# Fold 2/5
# Fold 2 Score: 0.9375
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.8800
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.9090
# Std deviation: 0.0185
# Testing k = 10
#   Repeat 1/20
#
# Fold 1/5
# Fold 1 Score: 0.8800
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.9090
# Std deviation: 0.0162
#   Repeat 2/20
#
# Fold 1/5
# Fold 1 Score: 0.9000
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.8975
#
# Cross-validation results:
# Mean score: 0.9105
# Std deviation: 0.0104
#   Repeat 3/20
#
# Fold 1/5
# Fold 1 Score: 0.9050
#
# Fold 2/5
# Fold 2 Score: 0.8875
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.8925
#
# Fold 5/5
# Fold 5 Score: 0.9450
#
# Cross-validation results:
# Mean score: 0.9080
# Std deviation: 0.0202
#   Repeat 4/20
#
# Fold 1/5
# Fold 1 Score: 0.9250
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.8875
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.8800
#
# Cross-validation results:
# Mean score: 0.9050
# Std deviation: 0.0186
#   Repeat 5/20
#
# Fold 1/5
# Fold 1 Score: 0.8950
#
# Fold 2/5
# Fold 2 Score: 0.9025
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.9030
# Std deviation: 0.0073
#   Repeat 6/20
#
# Fold 1/5
# Fold 1 Score: 0.9025
#
# Fold 2/5
# Fold 2 Score: 0.8975
#
# Fold 3/5
# Fold 3 Score: 0.9375
#
# Fold 4/5
# Fold 4 Score: 0.9000
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.9065
# Std deviation: 0.0157
#   Repeat 7/20
#
# Fold 1/5
# Fold 1 Score: 0.9025
#
# Fold 2/5
# Fold 2 Score: 0.9000
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.8975
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9085
# Std deviation: 0.0106
#   Repeat 8/20
#
# Fold 1/5
# Fold 1 Score: 0.8950
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9100
# Std deviation: 0.0129
#   Repeat 9/20
#
# Fold 1/5
# Fold 1 Score: 0.9075
#
# Fold 2/5
# Fold 2 Score: 0.8725
#
# Fold 3/5
# Fold 3 Score: 0.9025
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9050
# Std deviation: 0.0192
#   Repeat 10/20
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.8900
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.9075
# Std deviation: 0.0153
#   Repeat 11/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9000
#
# Fold 4/5
# Fold 4 Score: 0.8925
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9095
# Std deviation: 0.0118
#   Repeat 12/20
#
# Fold 1/5
# Fold 1 Score: 0.9125
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9110
# Std deviation: 0.0145
#   Repeat 13/20
#
# Fold 1/5
# Fold 1 Score: 0.8950
#
# Fold 2/5
# Fold 2 Score: 0.8900
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9085
# Std deviation: 0.0137
#   Repeat 14/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9300
#
# Fold 3/5
# Fold 3 Score: 0.9050
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9125
# Std deviation: 0.0101
#   Repeat 15/20
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.8775
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.8900
#
# Fold 5/5
# Fold 5 Score: 0.9175
#
# Cross-validation results:
# Mean score: 0.9055
# Std deviation: 0.0183
#   Repeat 16/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9100
#
# Fold 3/5
# Fold 3 Score: 0.8925
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9075
#
# Cross-validation results:
# Mean score: 0.9070
# Std deviation: 0.0081
#   Repeat 17/20
#
# Fold 1/5
# Fold 1 Score: 0.8975
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.9090
# Std deviation: 0.0094
#   Repeat 18/20
#
# Fold 1/5
# Fold 1 Score: 0.8925
#
# Fold 2/5
# Fold 2 Score: 0.9000
#
# Fold 3/5
# Fold 3 Score: 0.9475
#
# Fold 4/5
# Fold 4 Score: 0.8950
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9100
# Std deviation: 0.0203
#   Repeat 19/20
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.8925
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9115
# Std deviation: 0.0112
#   Repeat 20/20
#
# Fold 1/5
# Fold 1 Score: 0.9075
#
# Fold 2/5
# Fold 2 Score: 0.9200
#
# Fold 3/5
# Fold 3 Score: 0.9050
#
# Fold 4/5
# Fold 4 Score: 0.8825
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.9040
# Std deviation: 0.0121
# Testing k = 15
#   Repeat 1/20
#
# Fold 1/5
# Fold 1 Score: 0.8825
#
# Fold 2/5
# Fold 2 Score: 0.8925
#
# Fold 3/5
# Fold 3 Score: 0.9000
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.8975
# Std deviation: 0.0115
#   Repeat 2/20
#
# Fold 1/5
# Fold 1 Score: 0.8850
#
# Fold 2/5
# Fold 2 Score: 0.9150
#
# Fold 3/5
# Fold 3 Score: 0.8925
#
# Fold 4/5
# Fold 4 Score: 0.8975
#
# Fold 5/5
# Fold 5 Score: 0.8825
#
# Cross-validation results:
# Mean score: 0.8945
# Std deviation: 0.0116
#   Repeat 3/20
#
# Fold 1/5
# Fold 1 Score: 0.8950
#
# Fold 2/5
# Fold 2 Score: 0.8675
#
# Fold 3/5
# Fold 3 Score: 0.9025
#
# Fold 4/5
# Fold 4 Score: 0.8700
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.8930
# Std deviation: 0.0230
#   Repeat 4/20
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.8975
#
# Fold 3/5
# Fold 3 Score: 0.8825
#
# Fold 4/5
# Fold 4 Score: 0.8775
#
# Fold 5/5
# Fold 5 Score: 0.8750
#
# Cross-validation results:
# Mean score: 0.8885
# Std deviation: 0.0133
#   Repeat 5/20
#
# Fold 1/5
# Fold 1 Score: 0.8825
#
# Fold 2/5
# Fold 2 Score: 0.8800
#
# Fold 3/5
# Fold 3 Score: 0.9075
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.8875
#
# Cross-validation results:
# Mean score: 0.8930
# Std deviation: 0.0121
#   Repeat 6/20
#
# Fold 1/5
# Fold 1 Score: 0.8825
#
# Fold 2/5
# Fold 2 Score: 0.8850
#
# Fold 3/5
# Fold 3 Score: 0.9275
#
# Fold 4/5
# Fold 4 Score: 0.8750
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.8920
# Std deviation: 0.0184
#   Repeat 7/20
#
# Fold 1/5
# Fold 1 Score: 0.8800
#
# Fold 2/5
# Fold 2 Score: 0.8750
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.8850
#
# Fold 5/5
# Fold 5 Score: 0.9025
#
# Cross-validation results:
# Mean score: 0.8905
# Std deviation: 0.0135
#   Repeat 8/20
#
# Fold 1/5
# Fold 1 Score: 0.8850
#
# Fold 2/5
# Fold 2 Score: 0.8700
#
# Fold 3/5
# Fold 3 Score: 0.9075
#
# Fold 4/5
# Fold 4 Score: 0.8975
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.8965
# Std deviation: 0.0181
#   Repeat 9/20
#
# Fold 1/5
# Fold 1 Score: 0.9075
#
# Fold 2/5
# Fold 2 Score: 0.8575
#
# Fold 3/5
# Fold 3 Score: 0.8950
#
# Fold 4/5
# Fold 4 Score: 0.9125
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.8935
# Std deviation: 0.0193
#   Repeat 10/20
#
# Fold 1/5
# Fold 1 Score: 0.8925
#
# Fold 2/5
# Fold 2 Score: 0.9100
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.8675
#
# Fold 5/5
# Fold 5 Score: 0.8850
#
# Cross-validation results:
# Mean score: 0.8930
# Std deviation: 0.0161
#   Repeat 11/20
#
# Fold 1/5
# Fold 1 Score: 0.8950
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.8650
#
# Fold 4/5
# Fold 4 Score: 0.8825
#
# Fold 5/5
# Fold 5 Score: 0.8975
#
# Cross-validation results:
# Mean score: 0.8925
# Std deviation: 0.0189
#   Repeat 12/20
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.8625
#
# Fold 3/5
# Fold 3 Score: 0.9025
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.8950
# Std deviation: 0.0184
#   Repeat 13/20
#
# Fold 1/5
# Fold 1 Score: 0.8775
#
# Fold 2/5
# Fold 2 Score: 0.8725
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9025
#
# Fold 5/5
# Fold 5 Score: 0.9125
#
# Cross-validation results:
# Mean score: 0.8950
# Std deviation: 0.0167
#   Repeat 14/20
#
# Fold 1/5
# Fold 1 Score: 0.9150
#
# Fold 2/5
# Fold 2 Score: 0.9000
#
# Fold 3/5
# Fold 3 Score: 0.8800
#
# Fold 4/5
# Fold 4 Score: 0.8775
#
# Fold 5/5
# Fold 5 Score: 0.8875
#
# Cross-validation results:
# Mean score: 0.8920
# Std deviation: 0.0139
#   Repeat 15/20
#
# Fold 1/5
# Fold 1 Score: 0.8950
#
# Fold 2/5
# Fold 2 Score: 0.8500
#
# Fold 3/5
# Fold 3 Score: 0.9150
#
# Fold 4/5
# Fold 4 Score: 0.8900
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.8920
# Std deviation: 0.0229
#   Repeat 16/20
#
# Fold 1/5
# Fold 1 Score: 0.8975
#
# Fold 2/5
# Fold 2 Score: 0.8975
#
# Fold 3/5
# Fold 3 Score: 0.8850
#
# Fold 4/5
# Fold 4 Score: 0.8975
#
# Fold 5/5
# Fold 5 Score: 0.8925
#
# Cross-validation results:
# Mean score: 0.8940
# Std deviation: 0.0049
#   Repeat 17/20
#
# Fold 1/5
# Fold 1 Score: 0.8800
#
# Fold 2/5
# Fold 2 Score: 0.8950
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.8850
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.8940
# Std deviation: 0.0139
#   Repeat 18/20
#
# Fold 1/5
# Fold 1 Score: 0.8800
#
# Fold 2/5
# Fold 2 Score: 0.8900
#
# Fold 3/5
# Fold 3 Score: 0.9250
#
# Fold 4/5
# Fold 4 Score: 0.8700
#
# Fold 5/5
# Fold 5 Score: 0.9000
#
# Cross-validation results:
# Mean score: 0.8930
# Std deviation: 0.0189
#   Repeat 19/20
#
# Fold 1/5
# Fold 1 Score: 0.8775
#
# Fold 2/5
# Fold 2 Score: 0.8725
#
# Fold 3/5
# Fold 3 Score: 0.8750
#
# Fold 4/5
# Fold 4 Score: 0.9050
#
# Fold 5/5
# Fold 5 Score: 0.9125
#
# Cross-validation results:
# Mean score: 0.8885
# Std deviation: 0.0168
#   Repeat 20/20
#
# Fold 1/5
# Fold 1 Score: 0.9050
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.9000
#
# Fold 4/5
# Fold 4 Score: 0.8575
#
# Fold 5/5
# Fold 5 Score: 0.8800
#
# Cross-validation results:
# Mean score: 0.8900
# Std deviation: 0.0189
# Testing k = 25
#   Repeat 1/20
#
# Fold 1/5
# Fold 1 Score: 0.8500
#
# Fold 2/5
# Fold 2 Score: 0.8650
#
# Fold 3/5
# Fold 3 Score: 0.8750
#
# Fold 4/5
# Fold 4 Score: 0.9075
#
# Fold 5/5
# Fold 5 Score: 0.8800
#
# Cross-validation results:
# Mean score: 0.8755
# Std deviation: 0.0190
#   Repeat 2/20
#
# Fold 1/5
# Fold 1 Score: 0.8650
#
# Fold 2/5
# Fold 2 Score: 0.8875
#
# Fold 3/5
# Fold 3 Score: 0.8775
#
# Fold 4/5
# Fold 4 Score: 0.8800
#
# Fold 5/5
# Fold 5 Score: 0.8700
#
# Cross-validation results:
# Mean score: 0.8760
# Std deviation: 0.0078
#   Repeat 3/20
#
# Fold 1/5
# Fold 1 Score: 0.8725
#
# Fold 2/5
# Fold 2 Score: 0.8375
#
# Fold 3/5
# Fold 3 Score: 0.8825
#
# Fold 4/5
# Fold 4 Score: 0.8625
#
# Fold 5/5
# Fold 5 Score: 0.9125
#
# Cross-validation results:
# Mean score: 0.8735
# Std deviation: 0.0246
#   Repeat 4/20
#
# Fold 1/5
# Fold 1 Score: 0.8900
#
# Fold 2/5
# Fold 2 Score: 0.8900
#
# Fold 3/5
# Fold 3 Score: 0.8775
#
# Fold 4/5
# Fold 4 Score: 0.8750
#
# Fold 5/5
# Fold 5 Score: 0.8550
#
# Cross-validation results:
# Mean score: 0.8775
# Std deviation: 0.0128
#   Repeat 5/20
#
# Fold 1/5
# Fold 1 Score: 0.8650
#
# Fold 2/5
# Fold 2 Score: 0.8725
#
# Fold 3/5
# Fold 3 Score: 0.8825
#
# Fold 4/5
# Fold 4 Score: 0.8900
#
# Fold 5/5
# Fold 5 Score: 0.8475
#
# Cross-validation results:
# Mean score: 0.8715
# Std deviation: 0.0147
#   Repeat 6/20
#
# Fold 1/5
# Fold 1 Score: 0.8625
#
# Fold 2/5
# Fold 2 Score: 0.8600
#
# Fold 3/5
# Fold 3 Score: 0.9075
#
# Fold 4/5
# Fold 4 Score: 0.8675
#
# Fold 5/5
# Fold 5 Score: 0.8775
#
# Cross-validation results:
# Mean score: 0.8750
# Std deviation: 0.0173
#   Repeat 7/20
#
# Fold 1/5
# Fold 1 Score: 0.8700
#
# Fold 2/5
# Fold 2 Score: 0.8675
#
# Fold 3/5
# Fold 3 Score: 0.8925
#
# Fold 4/5
# Fold 4 Score: 0.8525
#
# Fold 5/5
# Fold 5 Score: 0.8900
#
# Cross-validation results:
# Mean score: 0.8745
# Std deviation: 0.0149
#   Repeat 8/20
#
# Fold 1/5
# Fold 1 Score: 0.8650
#
# Fold 2/5
# Fold 2 Score: 0.8475
#
# Fold 3/5
# Fold 3 Score: 0.8975
#
# Fold 4/5
# Fold 4 Score: 0.8775
#
# Fold 5/5
# Fold 5 Score: 0.8975
#
# Cross-validation results:
# Mean score: 0.8770
# Std deviation: 0.0193
#   Repeat 9/20
#
# Fold 1/5
# Fold 1 Score: 0.8800
#
# Fold 2/5
# Fold 2 Score: 0.8525
#
# Fold 3/5
# Fold 3 Score: 0.8525
#
# Fold 4/5
# Fold 4 Score: 0.9100
#
# Fold 5/5
# Fold 5 Score: 0.8650
#
# Cross-validation results:
# Mean score: 0.8720
# Std deviation: 0.0215
#   Repeat 10/20
#
# Fold 1/5
# Fold 1 Score: 0.8725
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.8900
#
# Fold 4/5
# Fold 4 Score: 0.8525
#
# Fold 5/5
# Fold 5 Score: 0.8625
#
# Cross-validation results:
# Mean score: 0.8720
# Std deviation: 0.0135
#   Repeat 11/20
#
# Fold 1/5
# Fold 1 Score: 0.8675
#
# Fold 2/5
# Fold 2 Score: 0.9050
#
# Fold 3/5
# Fold 3 Score: 0.8475
#
# Fold 4/5
# Fold 4 Score: 0.8600
#
# Fold 5/5
# Fold 5 Score: 0.8800
#
# Cross-validation results:
# Mean score: 0.8720
# Std deviation: 0.0196
#   Repeat 12/20
#
# Fold 1/5
# Fold 1 Score: 0.8925
#
# Fold 2/5
# Fold 2 Score: 0.8525
#
# Fold 3/5
# Fold 3 Score: 0.8725
#
# Fold 4/5
# Fold 4 Score: 0.8875
#
# Fold 5/5
# Fold 5 Score: 0.8425
#
# Cross-validation results:
# Mean score: 0.8695
# Std deviation: 0.0194
#   Repeat 13/20
#
# Fold 1/5
# Fold 1 Score: 0.8500
#
# Fold 2/5
# Fold 2 Score: 0.8550
#
# Fold 3/5
# Fold 3 Score: 0.8975
#
# Fold 4/5
# Fold 4 Score: 0.8800
#
# Fold 5/5
# Fold 5 Score: 0.8925
#
# Cross-validation results:
# Mean score: 0.8750
# Std deviation: 0.0193
#   Repeat 14/20
#
# Fold 1/5
# Fold 1 Score: 0.9025
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.8600
#
# Fold 4/5
# Fold 4 Score: 0.8650
#
# Fold 5/5
# Fold 5 Score: 0.8650
#
# Cross-validation results:
# Mean score: 0.8750
# Std deviation: 0.0157
#   Repeat 15/20
#
# Fold 1/5
# Fold 1 Score: 0.8750
#
# Fold 2/5
# Fold 2 Score: 0.8325
#
# Fold 3/5
# Fold 3 Score: 0.9025
#
# Fold 4/5
# Fold 4 Score: 0.8575
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.8725
# Std deviation: 0.0254
#   Repeat 16/20
#
# Fold 1/5
# Fold 1 Score: 0.8700
#
# Fold 2/5
# Fold 2 Score: 0.8650
#
# Fold 3/5
# Fold 3 Score: 0.8650
#
# Fold 4/5
# Fold 4 Score: 0.8825
#
# Fold 5/5
# Fold 5 Score: 0.8675
#
# Cross-validation results:
# Mean score: 0.8700
# Std deviation: 0.0065
#   Repeat 17/20
#
# Fold 1/5
# Fold 1 Score: 0.8675
#
# Fold 2/5
# Fold 2 Score: 0.8500
#
# Fold 3/5
# Fold 3 Score: 0.8950
#
# Fold 4/5
# Fold 4 Score: 0.8775
#
# Fold 5/5
# Fold 5 Score: 0.8675
#
# Cross-validation results:
# Mean score: 0.8715
# Std deviation: 0.0147
#   Repeat 18/20
#
# Fold 1/5
# Fold 1 Score: 0.8575
#
# Fold 2/5
# Fold 2 Score: 0.8825
#
# Fold 3/5
# Fold 3 Score: 0.9125
#
# Fold 4/5
# Fold 4 Score: 0.8500
#
# Fold 5/5
# Fold 5 Score: 0.8750
#
# Cross-validation results:
# Mean score: 0.8755
# Std deviation: 0.0219
#   Repeat 19/20
#
# Fold 1/5
# Fold 1 Score: 0.8625
#
# Fold 2/5
# Fold 2 Score: 0.8600
#
# Fold 3/5
# Fold 3 Score: 0.8650
#
# Fold 4/5
# Fold 4 Score: 0.8825
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.8750
# Std deviation: 0.0170
#   Repeat 20/20
#
# Fold 1/5
# Fold 1 Score: 0.8875
#
# Fold 2/5
# Fold 2 Score: 0.9025
#
# Fold 3/5
# Fold 3 Score: 0.8800
#
# Fold 4/5
# Fold 4 Score: 0.8475
#
# Fold 5/5
# Fold 5 Score: 0.8575
#
# Cross-validation results:
# Mean score: 0.8750
# Std deviation: 0.0200
# Testing k = 40
#   Repeat 1/20
#
# Fold 1/5
# Fold 1 Score: 0.8150
#
# Fold 2/5
# Fold 2 Score: 0.8225
#
# Fold 3/5
# Fold 3 Score: 0.8425
#
# Fold 4/5
# Fold 4 Score: 0.8675
#
# Fold 5/5
# Fold 5 Score: 0.8500
#
# Cross-validation results:
# Mean score: 0.8395
# Std deviation: 0.0189
#   Repeat 2/20
#
# Fold 1/5
# Fold 1 Score: 0.8300
#
# Fold 2/5
# Fold 2 Score: 0.8525
#
# Fold 3/5
# Fold 3 Score: 0.8650
#
# Fold 4/5
# Fold 4 Score: 0.8475
#
# Fold 5/5
# Fold 5 Score: 0.8375
#
# Cross-validation results:
# Mean score: 0.8465
# Std deviation: 0.0121
#   Repeat 3/20
#
# Fold 1/5
# Fold 1 Score: 0.8450
#
# Fold 2/5
# Fold 2 Score: 0.8100
#
# Fold 3/5
# Fold 3 Score: 0.8550
#
# Fold 4/5
# Fold 4 Score: 0.8325
#
# Fold 5/5
# Fold 5 Score: 0.8750
#
# Cross-validation results:
# Mean score: 0.8435
# Std deviation: 0.0218
#   Repeat 4/20
#
# Fold 1/5
# Fold 1 Score: 0.8700
#
# Fold 2/5
# Fold 2 Score: 0.8450
#
# Fold 3/5
# Fold 3 Score: 0.8475
#
# Fold 4/5
# Fold 4 Score: 0.8375
#
# Fold 5/5
# Fold 5 Score: 0.8250
#
# Cross-validation results:
# Mean score: 0.8450
# Std deviation: 0.0147
#   Repeat 5/20
#
# Fold 1/5
# Fold 1 Score: 0.8400
#
# Fold 2/5
# Fold 2 Score: 0.8400
#
# Fold 3/5
# Fold 3 Score: 0.8600
#
# Fold 4/5
# Fold 4 Score: 0.8675
#
# Fold 5/5
# Fold 5 Score: 0.8125
#
# Cross-validation results:
# Mean score: 0.8440
# Std deviation: 0.0191
#   Repeat 6/20
#
# Fold 1/5
# Fold 1 Score: 0.8275
#
# Fold 2/5
# Fold 2 Score: 0.8375
#
# Fold 3/5
# Fold 3 Score: 0.8875
#
# Fold 4/5
# Fold 4 Score: 0.8250
#
# Fold 5/5
# Fold 5 Score: 0.8425
#
# Cross-validation results:
# Mean score: 0.8440
# Std deviation: 0.0227
#   Repeat 7/20
#
# Fold 1/5
# Fold 1 Score: 0.8550
#
# Fold 2/5
# Fold 2 Score: 0.8250
#
# Fold 3/5
# Fold 3 Score: 0.8575
#
# Fold 4/5
# Fold 4 Score: 0.8225
#
# Fold 5/5
# Fold 5 Score: 0.8550
#
# Cross-validation results:
# Mean score: 0.8430
# Std deviation: 0.0158
#   Repeat 8/20
#
# Fold 1/5
# Fold 1 Score: 0.8250
#
# Fold 2/5
# Fold 2 Score: 0.8275
#
# Fold 3/5
# Fold 3 Score: 0.8650
#
# Fold 4/5
# Fold 4 Score: 0.8475
#
# Fold 5/5
# Fold 5 Score: 0.8725
#
# Cross-validation results:
# Mean score: 0.8475
# Std deviation: 0.0192
#   Repeat 9/20
#
# Fold 1/5
# Fold 1 Score: 0.8550
#
# Fold 2/5
# Fold 2 Score: 0.8150
#
# Fold 3/5
# Fold 3 Score: 0.8250
#
# Fold 4/5
# Fold 4 Score: 0.8950
#
# Fold 5/5
# Fold 5 Score: 0.8100
#
# Cross-validation results:
# Mean score: 0.8400
# Std deviation: 0.0316
#   Repeat 10/20
#
# Fold 1/5
# Fold 1 Score: 0.8500
#
# Fold 2/5
# Fold 2 Score: 0.8500
#
# Fold 3/5
# Fold 3 Score: 0.8675
#
# Fold 4/5
# Fold 4 Score: 0.8275
#
# Fold 5/5
# Fold 5 Score: 0.8325
#
# Cross-validation results:
# Mean score: 0.8455
# Std deviation: 0.0143
#   Repeat 11/20
#
# Fold 1/5
# Fold 1 Score: 0.8375
#
# Fold 2/5
# Fold 2 Score: 0.8875
#
# Fold 3/5
# Fold 3 Score: 0.8175
#
# Fold 4/5
# Fold 4 Score: 0.8275
#
# Fold 5/5
# Fold 5 Score: 0.8500
#
# Cross-validation results:
# Mean score: 0.8440
# Std deviation: 0.0243
#   Repeat 12/20
#
# Fold 1/5
# Fold 1 Score: 0.8475
#
# Fold 2/5
# Fold 2 Score: 0.8175
#
# Fold 3/5
# Fold 3 Score: 0.8600
#
# Fold 4/5
# Fold 4 Score: 0.8725
#
# Fold 5/5
# Fold 5 Score: 0.8125
#
# Cross-validation results:
# Mean score: 0.8420
# Std deviation: 0.0235
#   Repeat 13/20
#
# Fold 1/5
# Fold 1 Score: 0.8250
#
# Fold 2/5
# Fold 2 Score: 0.8325
#
# Fold 3/5
# Fold 3 Score: 0.8600
#
# Fold 4/5
# Fold 4 Score: 0.8575
#
# Fold 5/5
# Fold 5 Score: 0.8550
#
# Cross-validation results:
# Mean score: 0.8460
# Std deviation: 0.0144
#   Repeat 14/20
#
# Fold 1/5
# Fold 1 Score: 0.8675
#
# Fold 2/5
# Fold 2 Score: 0.8675
#
# Fold 3/5
# Fold 3 Score: 0.8250
#
# Fold 4/5
# Fold 4 Score: 0.8500
#
# Fold 5/5
# Fold 5 Score: 0.8325
#
# Cross-validation results:
# Mean score: 0.8485
# Std deviation: 0.0175
#   Repeat 15/20
#
# Fold 1/5
# Fold 1 Score: 0.8475
#
# Fold 2/5
# Fold 2 Score: 0.8100
#
# Fold 3/5
# Fold 3 Score: 0.8700
#
# Fold 4/5
# Fold 4 Score: 0.8300
#
# Fold 5/5
# Fold 5 Score: 0.8525
#
# Cross-validation results:
# Mean score: 0.8420
# Std deviation: 0.0205
#   Repeat 16/20
#
# Fold 1/5
# Fold 1 Score: 0.8675
#
# Fold 2/5
# Fold 2 Score: 0.8150
#
# Fold 3/5
# Fold 3 Score: 0.8300
#
# Fold 4/5
# Fold 4 Score: 0.8600
#
# Fold 5/5
# Fold 5 Score: 0.8400
#
# Cross-validation results:
# Mean score: 0.8425
# Std deviation: 0.0192
#   Repeat 17/20
#
# Fold 1/5
# Fold 1 Score: 0.8325
#
# Fold 2/5
# Fold 2 Score: 0.8275
#
# Fold 3/5
# Fold 3 Score: 0.8800
#
# Fold 4/5
# Fold 4 Score: 0.8575
#
# Fold 5/5
# Fold 5 Score: 0.8450
#
# Cross-validation results:
# Mean score: 0.8485
# Std deviation: 0.0189
#   Repeat 18/20
#
# Fold 1/5
# Fold 1 Score: 0.8375
#
# Fold 2/5
# Fold 2 Score: 0.8425
#
# Fold 3/5
# Fold 3 Score: 0.8950
#
# Fold 4/5
# Fold 4 Score: 0.8100
#
# Fold 5/5
# Fold 5 Score: 0.8550
#
# Cross-validation results:
# Mean score: 0.8480
# Std deviation: 0.0277
#   Repeat 19/20
#
# Fold 1/5
# Fold 1 Score: 0.8450
#
# Fold 2/5
# Fold 2 Score: 0.8275
#
# Fold 3/5
# Fold 3 Score: 0.8425
#
# Fold 4/5
# Fold 4 Score: 0.8650
#
# Fold 5/5
# Fold 5 Score: 0.8825
#
# Cross-validation results:
# Mean score: 0.8525
# Std deviation: 0.0192
#   Repeat 20/20
#
# Fold 1/5
# Fold 1 Score: 0.8325
#
# Fold 2/5
# Fold 2 Score: 0.8700
#
# Fold 3/5
# Fold 3 Score: 0.8500
#
# Fold 4/5
# Fold 4 Score: 0.8250
#
# Fold 5/5
# Fold 5 Score: 0.8375
#
# Cross-validation results:
# Mean score: 0.8430
# Std deviation: 0.0158
# k = 1, Sorted Accuracy Scores (100 values):
# [0.8875, 0.89, 0.89, 0.89, 0.8925, 0.895, 0.895, 0.8975, 0.8975, 0.8975, 0.9, 0.9, 0.9, 0.9025, 0.9025, 0.9025, 0.9025, 0.905, 0.905, 0.905, 0.905, 0.905, 0.905, 0.9075, 0.9075, 0.91, 0.91, 0.91, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.915, 0.915, 0.915, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.93, 0.93, 0.93, 0.93, 0.9325, 0.9325, 0.935, 0.935, 0.9375, 0.9375, 0.94, 0.94, 0.94, 0.9425, 0.9425, 0.9425, 0.945, 0.945]
#
# k = 3, Sorted Accuracy Scores (100 values):
# [0.875, 0.8825, 0.89, 0.8925, 0.8925, 0.8975, 0.8975, 0.9, 0.9, 0.9025, 0.9025, 0.9025, 0.9025, 0.9025, 0.905, 0.905, 0.905, 0.9075, 0.9075, 0.91, 0.91, 0.91, 0.91, 0.91, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.915, 0.915, 0.915, 0.915, 0.915, 0.915, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.925, 0.925, 0.925, 0.925, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.9325, 0.9325, 0.9325, 0.9325, 0.9325, 0.935, 0.935, 0.935, 0.9375, 0.9375, 0.9375, 0.9375, 0.9375, 0.94, 0.94, 0.9425, 0.9425, 0.9425, 0.9425, 0.9425, 0.9425, 0.95]
#
# k = 5, Sorted Accuracy Scores (100 values):
# [0.875, 0.8825, 0.885, 0.89, 0.8925, 0.8925, 0.8925, 0.8925, 0.895, 0.895, 0.8975, 0.9, 0.9025, 0.905, 0.905, 0.905, 0.905, 0.905, 0.9075, 0.9075, 0.9075, 0.9075, 0.9075, 0.9075, 0.9075, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.915, 0.915, 0.915, 0.915, 0.915, 0.915, 0.915, 0.915, 0.915, 0.915, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.92, 0.92, 0.92, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.9275, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.93, 0.9325, 0.9325, 0.9325, 0.9325, 0.935, 0.935, 0.9375, 0.9375, 0.94, 0.94, 0.94, 0.9425, 0.945, 0.9475, 0.95]
#
# k = 7, Sorted Accuracy Scores (100 values):
# [0.8725, 0.88, 0.8825, 0.8825, 0.8825, 0.885, 0.8875, 0.8875, 0.89, 0.8925, 0.8925, 0.8925, 0.8925, 0.8925, 0.8925, 0.895, 0.895, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.9, 0.9, 0.9, 0.9025, 0.9025, 0.9025, 0.9025, 0.905, 0.905, 0.905, 0.905, 0.905, 0.9075, 0.9075, 0.9075, 0.9075, 0.9075, 0.9075, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.915, 0.915, 0.915, 0.915, 0.915, 0.915, 0.915, 0.915, 0.9175, 0.9175, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.9225, 0.925, 0.925, 0.925, 0.925, 0.9275, 0.9275, 0.9275, 0.9275, 0.93, 0.93, 0.93, 0.93, 0.9325, 0.9325, 0.9325, 0.9325, 0.9325, 0.935, 0.9375, 0.94, 0.94, 0.945]
#
# k = 10, Sorted Accuracy Scores (100 values):
# [0.8725, 0.8775, 0.88, 0.88, 0.8825, 0.8825, 0.8875, 0.8875, 0.89, 0.89, 0.89, 0.89, 0.8925, 0.8925, 0.8925, 0.8925, 0.8925, 0.895, 0.895, 0.895, 0.895, 0.895, 0.895, 0.895, 0.8975, 0.8975, 0.8975, 0.8975, 0.9, 0.9, 0.9, 0.9, 0.9, 0.9025, 0.9025, 0.9025, 0.9025, 0.9025, 0.9025, 0.905, 0.905, 0.905, 0.905, 0.905, 0.905, 0.9075, 0.9075, 0.9075, 0.9075, 0.9075, 0.9075, 0.9075, 0.91, 0.91, 0.91, 0.91, 0.91, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.9125, 0.915, 0.915, 0.915, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.9175, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.92, 0.9225, 0.9225, 0.9225, 0.925, 0.925, 0.925, 0.925, 0.925, 0.925, 0.9275, 0.9275, 0.9275, 0.93, 0.9325, 0.9375, 0.945, 0.9475]
#
# k = 15, Sorted Accuracy Scores (100 values):
# [0.85, 0.8575, 0.8575, 0.8625, 0.865, 0.8675, 0.8675, 0.87, 0.87, 0.87, 0.8725, 0.8725, 0.875, 0.875, 0.875, 0.875, 0.8775, 0.8775, 0.8775, 0.8775, 0.88, 0.88, 0.88, 0.88, 0.88, 0.88, 0.8825, 0.8825, 0.8825, 0.8825, 0.8825, 0.8825, 0.885, 0.885, 0.885, 0.885, 0.885, 0.885, 0.885, 0.8875, 0.8875, 0.89, 0.89, 0.89, 0.89, 0.89, 0.8925, 0.8925, 0.8925, 0.8925, 0.895, 0.895, 0.895, 0.895, 0.895, 0.895, 0.895, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.8975, 0.9, 0.9, 0.9, 0.9, 0.9025, 0.9025, 0.9025, 0.9025, 0.9025, 0.905, 0.905, 0.9075, 0.9075, 0.9075, 0.9075, 0.9075, 0.91, 0.91, 0.91, 0.91, 0.91, 0.91, 0.9125, 0.9125, 0.9125, 0.915, 0.915, 0.915, 0.9175, 0.9175, 0.92, 0.9225, 0.9225, 0.925, 0.9275, 0.93]
#
# k = 25, Sorted Accuracy Scores (100 values):
# [0.8325, 0.8375, 0.8425, 0.8475, 0.8475, 0.8475, 0.8475, 0.85, 0.85, 0.85, 0.85, 0.8525, 0.8525, 0.8525, 0.8525, 0.8525, 0.855, 0.855, 0.8575, 0.8575, 0.8575, 0.86, 0.86, 0.86, 0.86, 0.8625, 0.8625, 0.8625, 0.8625, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865, 0.865, 0.8675, 0.8675, 0.8675, 0.8675, 0.8675, 0.8675, 0.87, 0.87, 0.87, 0.8725, 0.8725, 0.8725, 0.8725, 0.875, 0.875, 0.875, 0.875, 0.8775, 0.8775, 0.8775, 0.8775, 0.8775, 0.88, 0.88, 0.88, 0.88, 0.88, 0.88, 0.8825, 0.8825, 0.8825, 0.8825, 0.8825, 0.8825, 0.8825, 0.8875, 0.8875, 0.8875, 0.89, 0.89, 0.89, 0.89, 0.89, 0.8925, 0.8925, 0.8925, 0.895, 0.895, 0.8975, 0.8975, 0.8975, 0.9025, 0.9025, 0.9025, 0.905, 0.905, 0.9075, 0.9075, 0.91, 0.9125, 0.9125]
#
# k = 40, Sorted Accuracy Scores (100 values):
# [0.81, 0.81, 0.81, 0.81, 0.8125, 0.8125, 0.815, 0.815, 0.815, 0.8175, 0.8175, 0.8225, 0.8225, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.825, 0.8275, 0.8275, 0.8275, 0.8275, 0.8275, 0.8275, 0.83, 0.83, 0.83, 0.8325, 0.8325, 0.8325, 0.8325, 0.8325, 0.8325, 0.8375, 0.8375, 0.8375, 0.8375, 0.8375, 0.8375, 0.84, 0.84, 0.84, 0.8425, 0.8425, 0.8425, 0.8425, 0.845, 0.845, 0.845, 0.845, 0.8475, 0.8475, 0.8475, 0.8475, 0.8475, 0.85, 0.85, 0.85, 0.85, 0.85, 0.85, 0.8525, 0.8525, 0.855, 0.855, 0.855, 0.855, 0.855, 0.855, 0.8575, 0.8575, 0.8575, 0.86, 0.86, 0.86, 0.86, 0.865, 0.865, 0.865, 0.8675, 0.8675, 0.8675, 0.8675, 0.8675, 0.8675, 0.87, 0.87, 0.87, 0.8725, 0.8725, 0.875, 0.88, 0.8825, 0.8875, 0.8875, 0.895, 0.895]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming all_results contains accuracy scores per k
k_values = [1, 3, 5, 7, 10, 15, 25, 40]

# Convert accuracy to error (1 - accuracy) for each score
error_results = [[1 - score for score in scores] for scores in all_results]

plt.figure(figsize=(10, 6))
plt.boxplot(error_results, labels=[str(k) for k in k_values], patch_artist=True)
plt.title("k-NN Classification Error vs Number of Neighbors")
plt.xlabel("Number of Neighbors (k)")
plt.ylabel("Classification Error (1 - Accuracy)")
plt.grid(True)
plt.show()
# Out:
# C:\Users\Nils\AppData\Local\Temp\ipykernel_17508\1197251268.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(error_results, labels=[str(k) for k in k_values], patch_artist=True)

# %%
#PCA tuning with cross-validation
max_iter_values = [100, 200, 500, 1000, 3000, 5000, 10000]
repeats = 20
all_results = []

images, labels = read_mnist_txt("Numbers.txt")
flat_images = images.reshape(len(images), -1)
flat_images = StandardScaler().fit_transform(flat_images)

for max_iter in max_iter_values:
    print(max_iter)
    print(f"Testing max_iter = {max_iter}")
    scores_iter = []

    for rep in range(repeats):
        scores = cross_validate(
            random_state=42 + rep,
            images=flat_images,
            labels=labels,
            train_fn=lambda X, y: train_PCA(X, y, max_iter=max_iter),
            predict_fn=predict_with_PCA,
            k_folds=5,
            metric_fn=accuracy_score
        )
        scores_iter.extend(scores)

    all_results.append(scores_iter)

pca_errors = [1 - np.mean(scores) for scores in all_results]

plt.figure(figsize=(10, 6))
plt.plot(max_iter_values, pca_errors, marker='^', linestyle='-', color='orange')
plt.title("Mean Classification Error vs max_iter (PCA Classifier)")
plt.xlabel("max_iter")
plt.ylabel("Mean Classification Error")
plt.grid(True)
plt.show()
# Out:
# Starting cross-validation...
#
# Testing max_iter = 100
#   Repeat 1/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.8600
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.8025
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.8025
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.8250
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.7825
#
# Cross-validation results:
# Mean score: 0.8145
# Std deviation: 0.0264
#   Repeat 2/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.8300
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.8100
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.7975
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.7850
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.8275
#
# Cross-validation results:
# Mean score: 0.8100
# Std deviation: 0.0172
#   Repeat 3/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.7875
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.7925
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.8125
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.8300
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.8100
#
# Cross-validation results:
# Mean score: 0.8065
# Std deviation: 0.0152
#   Repeat 4/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.7875
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.8100
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.8225
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.8050
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.8150
#
# Cross-validation results:
# Mean score: 0.8080
# Std deviation: 0.0118
#   Repeat 5/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.7925
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.8225
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.8300
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.7950
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.7975
#
# Cross-validation results:
# Mean score: 0.8075
# Std deviation: 0.0156
# Testing max_iter = 500
#   Repeat 1/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.9250
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9000
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9150
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.8700
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9040
# Std deviation: 0.0188
#   Repeat 2/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.8725
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9200
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9125
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.9050
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9070
# Std deviation: 0.0185
#   Repeat 3/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.9175
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.8950
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9150
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.9025
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.9070
# Std deviation: 0.0083
#   Repeat 4/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.8825
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9000
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9200
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.8975
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9040
# Std deviation: 0.0144
#   Repeat 5/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.8900
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9250
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9275
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.8925
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9090
# Std deviation: 0.0157
# Testing max_iter = 1000
#   Repeat 1/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.9350
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9175
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9300
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.9075
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9125
#
# Cross-validation results:
# Mean score: 0.9205
# Std deviation: 0.0104
#   Repeat 2/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.9175
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9150
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9125
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.9150
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9125
#
# Cross-validation results:
# Mean score: 0.9145
# Std deviation: 0.0019
#   Repeat 3/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.9075
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9125
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9250
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.9350
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9450
#
# Cross-validation results:
# Mean score: 0.9250
# Std deviation: 0.0139
#   Repeat 4/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.9050
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9275
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9300
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.9300
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9200
#
# Cross-validation results:
# Mean score: 0.9225
# Std deviation: 0.0095
#   Repeat 5/5
#
# Fold 1/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.8975
#
# Fold 2/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.8950
#
# Fold 3/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9025
#
# Fold 4/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.9450
#
# Fold 5/5
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9160
# Std deviation: 0.0218
# Testing max_iter = 3000
#   Repeat 1/5
#
# Fold 1/5
# Fold 1 Score: 0.9200
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.9050
#
# Cross-validation results:
# Mean score: 0.9215
# Std deviation: 0.0097
#   Repeat 2/5
#
# Fold 1/5
# Fold 1 Score: 0.9350
#
# Fold 2/5
# Fold 2 Score: 0.9350
#
# Fold 3/5
# Fold 3 Score: 0.9200
#
# Fold 4/5
# Fold 4 Score: 0.9300
#
# Fold 5/5
# Fold 5 Score: 0.8950
#
# Cross-validation results:
# Mean score: 0.9230
# Std deviation: 0.0150
#   Repeat 3/5
#
# Fold 1/5
# Fold 1 Score: 0.9425
#
# Fold 2/5
# Fold 2 Score: 0.9225
#
# Fold 3/5
# Fold 3 Score: 0.8975
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9250
#
# Cross-validation results:
# Mean score: 0.9210
# Std deviation: 0.0145
#   Repeat 4/5
#
# Fold 1/5
# Fold 1 Score: 0.9350
#
# Fold 2/5
# Fold 2 Score: 0.9275
#
# Fold 3/5
# Fold 3 Score: 0.9225
#
# Fold 4/5
# Fold 4 Score: 0.9150
#
# Fold 5/5
# Fold 5 Score: 0.9100
#
# Cross-validation results:
# Mean score: 0.9220
# Std deviation: 0.0089
#   Repeat 5/5
#
# Fold 1/5
# Fold 1 Score: 0.9100
#
# Fold 2/5
# Fold 2 Score: 0.9325
#
# Fold 3/5
# Fold 3 Score: 0.9175
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9225
#
# Cross-validation results:
# Mean score: 0.9200
# Std deviation: 0.0074
# Testing max_iter = 5000
#   Repeat 1/5
#
# Fold 1/5
# Fold 1 Score: 0.9325
#
# Fold 2/5
# Fold 2 Score: 0.9125
#
# Fold 3/5
# Fold 3 Score: 0.9350
#
# Fold 4/5
# Fold 4 Score: 0.9325
#
# Fold 5/5
# Fold 5 Score: 0.9400
#
# Cross-validation results:
# Mean score: 0.9305
# Std deviation: 0.0094
#   Repeat 2/5
#
# Fold 1/5
# Fold 1 Score: 0.9175
#
# Fold 2/5
# Fold 2 Score: 0.9175
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9275
#
# Fold 5/5
# Fold 5 Score: 0.9450
#
# Cross-validation results:
# Mean score: 0.9235
# Std deviation: 0.0121
#   Repeat 3/5
#
# Fold 1/5
# Fold 1 Score: 0.9375
#
# Fold 2/5
# Fold 2 Score: 0.9075
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9350
#
# Fold 5/5
# Fold 5 Score: 0.9300
#
# Cross-validation results:
# Mean score: 0.9240
# Std deviation: 0.0127
#   Repeat 4/5
#
# Fold 1/5
# Fold 1 Score: 0.9275
#
# Fold 2/5
# Fold 2 Score: 0.9250
#
# Fold 3/5
# Fold 3 Score: 0.9325
#
# Fold 4/5
# Fold 4 Score: 0.9200
#
# Fold 5/5
# Fold 5 Score: 0.9275
#
# Cross-validation results:
# Mean score: 0.9265
# Std deviation: 0.0041
#   Repeat 5/5
#
# Fold 1/5
# Fold 1 Score: 0.9225
#
# Fold 2/5
# Fold 2 Score: 0.9350
#
# Fold 3/5
# Fold 3 Score: 0.9100
#
# Fold 4/5
# Fold 4 Score: 0.9175
#
# Fold 5/5
# Fold 5 Score: 0.9150
#
# Cross-validation results:
# Mean score: 0.9200
# Std deviation: 0.0085
# C:\Users\Nils\AppData\Local\Temp\ipykernel_24980\4165643004.py:37: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(all_results, labels=[f"max_iter={mi}" for mi in max_iter_values], patch_artist=True)
# max_iter = 100, Sorted Accuracy Scores (25 values):
# [0.7825, 0.785, 0.7875, 0.7875, 0.7925, 0.7925, 0.795, 0.7975, 0.7975, 0.8025, 0.8025, 0.805, 0.81, 0.81, 0.81, 0.8125, 0.815, 0.8225, 0.8225, 0.825, 0.8275, 0.83, 0.83, 0.83, 0.86]
#
# max_iter = 500, Sorted Accuracy Scores (25 values):
# [0.87, 0.8725, 0.8825, 0.89, 0.8925, 0.895, 0.8975, 0.9, 0.9, 0.9025, 0.905, 0.905, 0.91, 0.91, 0.9125, 0.915, 0.915, 0.9175, 0.92, 0.92, 0.92, 0.925, 0.925, 0.925, 0.9275]
#
# max_iter = 1000, Sorted Accuracy Scores (25 values):
# [0.895, 0.8975, 0.9025, 0.905, 0.9075, 0.9075, 0.9125, 0.9125, 0.9125, 0.9125, 0.915, 0.915, 0.9175, 0.9175, 0.92, 0.925, 0.9275, 0.93, 0.93, 0.93, 0.935, 0.935, 0.94, 0.945, 0.945]
#
# max_iter = 3000, Sorted Accuracy Scores (25 values):
# [0.895, 0.8975, 0.905, 0.91, 0.91, 0.915, 0.9175, 0.9175, 0.9175, 0.92, 0.92, 0.92, 0.9225, 0.9225, 0.9225, 0.925, 0.9275, 0.93, 0.93, 0.9325, 0.9325, 0.935, 0.935, 0.935, 0.9425]
#
# max_iter = 5000, Sorted Accuracy Scores (25 values):
# [0.9075, 0.91, 0.91, 0.91, 0.9125, 0.915, 0.9175, 0.9175, 0.9175, 0.92, 0.9225, 0.925, 0.9275, 0.9275, 0.9275, 0.93, 0.9325, 0.9325, 0.9325, 0.935, 0.935, 0.935, 0.9375, 0.94, 0.945]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

max_iter_values = [100, 200, 500, 1000, 3000, 5000, 10000]
repeats = 12 
all_results = []

for max_iter in max_iter_values:
    scores_max_iter = []

    for rep in range(repeats):
        scores = cross_validate(
            random_state=42 + rep,
            images=images,
            labels=labels,
            train_fn=lambda train_images, train_labels: train_PCA(train_images, train_labels, max_iter=max_iter),
            predict_fn=predict_with_PCA,
            k_folds=5,
            metric_fn=accuracy_score
        )
        scores_max_iter.extend(scores)

    all_results.append(scores_max_iter)

# Convert accuracy to error
error_results = [[1 - score for score in scores] for scores in all_results]

plt.figure(figsize=(10, 6))
plt.boxplot(error_results, labels=[f"{mi}" for mi in max_iter_values], patch_artist=True)
plt.title("PCA+MLP Classification Error vs max_iter")
plt.xlabel("max_iter")
plt.ylabel("Classification Error (1 - Accuracy)")
plt.grid(True)
plt.show()
# Out:
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.7925
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.7800
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.8175
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.8350
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.8350
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.8850
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9050
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9050
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.9425
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 5 Score: 0.9200
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 1 Score: 0.8975
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 2 Score: 0.9150
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 3 Score: 0.9200
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Fold 4 Score: 0.9525
# Fold 5 Score: 0.9275
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Nils\AppData\Local\Temp\ipykernel_17508\649058122.py:30: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(error_results, labels=[f"{mi}" for mi in max_iter_values], patch_artist=True)

# %%
#CV + tune CNN
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import torch

# Define the number of epochs to test
epoch_values = [1, 3, 5, 10, 20,30, 50, 100]
repeats = 12
errors_by_epoch = []

# Load data
images, labels = read_mnist_txt("Numbers.txt")

for epochs in epoch_values:
    print(epochs)
    print(f"Testing epochs = {epochs}")
    scores_e = []

    for rep in range(repeats):
        scores = cross_validate(
            random_state=42 + rep,
            images=images,
            labels=labels,
            train_fn=lambda X, y: train_cnn(X, y, lr=0.001, epochs=epochs),
            predict_fn=predict_with__cnn,
            k_folds=5,
            metric_fn=accuracy_score
        )
        scores_e.extend(scores)

    all_results.append(scores_e)

cnn_errors = [1 - np.mean(scores) for scores in all_results]

plt.figure(figsize=(10, 6))
plt.plot(epoch_values, cnn_errors, marker='D', linestyle='-', color='teal')
plt.title("Mean Classification Error vs Number of Epochs (CNN)")
plt.xlabel("Epochs")
plt.ylabel("Mean Classification Error")
plt.grid(True)
plt.show()
# Out:
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# Testing epochs = 1
#   Repeat 1/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 50/50 [00:00<00:00, 56.34it/s, v_num=95]
#     Accuracy: 0.1675  =>  Error: 0.8325
#   Repeat 2/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 50/50 [00:00<00:00, 65.88it/s, v_num=96]
#     Accuracy: 0.1650  =>  Error: 0.8350
#   Repeat 3/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 50/50 [00:00<00:00, 65.78it/s, v_num=97]
#     Accuracy: 0.1775  =>  Error: 0.8225
#   Repeat 4/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 50/50 [00:00<00:00, 58.91it/s, v_num=98]
#     Accuracy: 0.1650  =>  Error: 0.8350
#   Repeat 5/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 50/50 [00:00<00:00, 67.32it/s, v_num=99]
#     Accuracy: 0.2900  =>  Error: 0.7100
#   Repeat 6/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 50/50 [00:00<00:00, 68.55it/s, v_num=100]
#     Accuracy: 0.2500  =>  Error: 0.7500
#   Repeat 7/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 50/50 [00:00<00:00, 67.93it/s, v_num=101]
#     Accuracy: 0.2100  =>  Error: 0.7900
#   Repeat 8/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 50/50 [00:00<00:00, 75.28it/s, v_num=102]
#     Accuracy: 0.1575  =>  Error: 0.8425
# Testing epochs = 3
#   Repeat 1/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 2: 100%|██████████| 50/50 [00:00<00:00, 68.67it/s, v_num=103]
#     Accuracy: 0.2825  =>  Error: 0.7175
#   Repeat 2/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 2: 100%|██████████| 50/50 [00:00<00:00, 67.44it/s, v_num=104]
#     Accuracy: 0.1650  =>  Error: 0.8350
#   Repeat 3/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 2: 100%|██████████| 50/50 [00:00<00:00, 73.72it/s, v_num=105]
#     Accuracy: 0.1775  =>  Error: 0.8225
#   Repeat 4/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 2: 100%|██████████| 50/50 [00:00<00:00, 69.15it/s, v_num=106]
#     Accuracy: 0.2775  =>  Error: 0.7225
#   Repeat 5/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 2: 100%|██████████| 50/50 [00:00<00:00, 71.01it/s, v_num=107]
#     Accuracy: 0.1900  =>  Error: 0.8100
#   Repeat 6/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 2: 100%|██████████| 50/50 [00:00<00:00, 67.02it/s, v_num=108]
#     Accuracy: 0.2975  =>  Error: 0.7025
#   Repeat 7/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 2: 100%|██████████| 50/50 [00:00<00:00, 70.33it/s, v_num=109]
#     Accuracy: 0.1500  =>  Error: 0.8500
#   Repeat 8/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 2: 100%|██████████| 50/50 [00:00<00:00, 63.86it/s, v_num=110]
#     Accuracy: 0.1575  =>  Error: 0.8425
# Testing epochs = 5
#   Repeat 1/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 4: 100%|██████████| 50/50 [00:00<00:00, 73.19it/s, v_num=111]
#     Accuracy: 0.4950  =>  Error: 0.5050
#   Repeat 2/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 4: 100%|██████████| 50/50 [00:00<00:00, 64.52it/s, v_num=112]
#     Accuracy: 0.2950  =>  Error: 0.7050
#   Repeat 3/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 4: 100%|██████████| 50/50 [00:00<00:00, 72.55it/s, v_num=113]
#     Accuracy: 0.1775  =>  Error: 0.8225
#   Repeat 4/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 4: 100%|██████████| 50/50 [00:00<00:00, 61.67it/s, v_num=114]
#     Accuracy: 0.1650  =>  Error: 0.8350
#   Repeat 5/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 4: 100%|██████████| 50/50 [00:00<00:00, 71.42it/s, v_num=115]
#     Accuracy: 0.1750  =>  Error: 0.8250
#   Repeat 6/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 4: 100%|██████████| 50/50 [00:00<00:00, 71.93it/s, v_num=116]
#     Accuracy: 0.1800  =>  Error: 0.8200
#   Repeat 7/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 4: 100%|██████████| 50/50 [00:00<00:00, 68.12it/s, v_num=117]
#     Accuracy: 0.4925  =>  Error: 0.5075
#   Repeat 8/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 4: 100%|██████████| 50/50 [00:00<00:00, 74.27it/s, v_num=118]
#     Accuracy: 0.1575  =>  Error: 0.8425
# Testing epochs = 7
#   Repeat 1/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 6: 100%|██████████| 50/50 [00:00<00:00, 60.09it/s, v_num=119]
#     Accuracy: 0.5250  =>  Error: 0.4750
#   Repeat 2/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 6: 100%|██████████| 50/50 [00:00<00:00, 71.11it/s, v_num=120]
#     Accuracy: 0.4325  =>  Error: 0.5675
#   Repeat 3/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 6: 100%|██████████| 50/50 [00:00<00:00, 71.31it/s, v_num=121]
#     Accuracy: 0.6375  =>  Error: 0.3625
#   Repeat 4/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 6: 100%|██████████| 50/50 [00:00<00:00, 71.42it/s, v_num=122]
#     Accuracy: 0.2175  =>  Error: 0.7825
#   Repeat 5/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 6: 100%|██████████| 50/50 [00:00<00:00, 62.12it/s, v_num=123]
#     Accuracy: 0.4550  =>  Error: 0.5450
#   Repeat 6/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 6: 100%|██████████| 50/50 [00:00<00:00, 63.77it/s, v_num=124]
#     Accuracy: 0.5900  =>  Error: 0.4100
#   Repeat 7/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 6: 100%|██████████| 50/50 [00:00<00:00, 62.82it/s, v_num=125]
#     Accuracy: 0.5825  =>  Error: 0.4175
#   Repeat 8/8
# ...
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 19: 100%|██████████| 50/50 [00:00<00:00, 67.94it/s, v_num=149]
#     Accuracy: 0.7175  =>  Error: 0.2825
#   Repeat 8/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 19: 100%|██████████| 50/50 [00:00<00:00, 58.53it/s, v_num=150]
#     Accuracy: 0.9000  =>  Error: 0.1000
# Testing epochs = 30
#   Repeat 1/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 29: 100%|██████████| 50/50 [00:00<00:00, 68.17it/s, v_num=151]
#     Accuracy: 0.8775  =>  Error: 0.1225
#   Repeat 2/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 29: 100%|██████████| 50/50 [00:00<00:00, 69.63it/s, v_num=152]
#     Accuracy: 0.1650  =>  Error: 0.8350
#   Repeat 3/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 29: 100%|██████████| 50/50 [00:00<00:00, 61.42it/s, v_num=153]
#     Accuracy: 0.9000  =>  Error: 0.1000
#   Repeat 4/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 29: 100%|██████████| 50/50 [00:00<00:00, 67.20it/s, v_num=154]
#     Accuracy: 0.7775  =>  Error: 0.2225
#   Repeat 5/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 29: 100%|██████████| 50/50 [00:00<00:00, 61.74it/s, v_num=155]
#     Accuracy: 0.8950  =>  Error: 0.1050
#   Repeat 6/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 29: 100%|██████████| 50/50 [00:00<00:00, 73.73it/s, v_num=156]
#     Accuracy: 0.8825  =>  Error: 0.1175
#   Repeat 7/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 29: 100%|██████████| 50/50 [00:00<00:00, 73.40it/s, v_num=157]
#     Accuracy: 0.1900  =>  Error: 0.8100
#   Repeat 8/8
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#
#   | Name          | Type             | Params | Mode
# -----------------------------------------------------------
# 0 | loss          | CrossEntropyLoss | 0      | eval
# 1 | train_metrics | MetricCollection | 0      | train
# 2 | val_metrics   | MetricCollection | 0      | train
# 3 | test_metrics  | MetricCollection | 0      | train
# 4 | model         | Sequential       | 19.7 K | train
# 5 | loss_fn       | NLLLoss          | 0      | train
# 6 | optimizer     | RMSprop          | 0      | train
# -----------------------------------------------------------
# 19.7 K    Trainable params
# 0         Non-trainable params
# 19.7 K    Total params
# 0.079     Total estimated model params size (MB)
# 30        Modules in train mode
# 1         Modules in eval mode
# C:\Users\Nils\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\lightning\pytorch\trainer\connectors\data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# Epoch 29: 100%|██████████| 50/50 [00:00<00:00, 76.42it/s, v_num=158]
#     Accuracy: 0.8450  =>  Error: 0.1550
# C:\Users\Nils\AppData\Local\Temp\ipykernel_24980\1151967944.py:38: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(errors_by_epoch, labels=[str(e) for e in epoch_values], patch_artist=True)
# epochs = 1, Sorted Errors (8 values):
# [0.71, 0.75, 0.79, 0.8225, 0.8325, 0.835, 0.835, 0.8425]
#
# epochs = 3, Sorted Errors (8 values):
# [0.7025, 0.7175, 0.7224999999999999, 0.81, 0.8225, 0.835, 0.8425, 0.85]
#
# epochs = 5, Sorted Errors (8 values):
# [0.505, 0.5075000000000001, 0.7050000000000001, 0.8200000000000001, 0.8225, 0.825, 0.835, 0.8425]
#
# epochs = 7, Sorted Errors (8 values):
# [0.3325, 0.36250000000000004, 0.41000000000000003, 0.4175, 0.475, 0.5449999999999999, 0.5675, 0.7825]
#
# epochs = 10, Sorted Errors (8 values):
# [0.24250000000000005, 0.36, 0.36750000000000005, 0.4375, 0.45499999999999996, 0.6174999999999999, 0.8225, 0.835]
#
# epochs = 15, Sorted Errors (8 values):
# [0.14749999999999996, 0.31499999999999995, 0.32999999999999996, 0.43999999999999995, 0.5275000000000001, 0.81, 0.8200000000000001, 0.8325]
#
# epochs = 20, Sorted Errors (8 values):
# [0.09999999999999998, 0.135, 0.15500000000000003, 0.1725, 0.22999999999999998, 0.2825, 0.31000000000000005, 0.8325]
#
# epochs = 30, Sorted Errors (8 values):
# [0.09999999999999998, 0.10499999999999998, 0.11750000000000005, 0.12250000000000005, 0.15500000000000003, 0.22250000000000003, 0.81, 0.835]

# %%
cnn_mean_errors = [np.mean(errs) for errs in errors_by_epoch]

plt.figure(figsize=(8, 5))
plt.plot(epoch_values, cnn_mean_errors, marker='o', linestyle='-', color='blue')
plt.title("Mean Classification Error vs. Epochs (CNN)")
plt.xlabel("Number of Epochs")
plt.ylabel("Mean Classification Error")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cnn_mean_errors = [np.mean(errs) for errs in errors_by_epoch]
#       3 plt.figure(figsize=(8, 5))
#       4 plt.plot(epoch_values, cnn_mean_errors, marker='o', linestyle='-', color='blue')
#
# NameError: name 'errors_by_epoch' is not defined
